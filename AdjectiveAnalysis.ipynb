# %%
import spacy
import pandas as pd
import numpy as np
import pickle
import random

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def read_pickle_file(filename):
    with open(filename, "rb") as f:
        d = pickle.load(f)
    return d


def read_excel(filename):
    df = pd.read_excel(filename)
    return

# %% [markdown]
# ## 2020-2019 data

# %%
paper2020 = read_pickle_file('ICLR data/papers_2020.pkl')
decision2020 = read_pickle_file('ICLR data/paper_decision_dict_2020.pkl')

paper2019 = read_pickle_file('ICLR data/papers_2019.pkl')
decision2019 = read_pickle_file('ICLR data/paper_decision_dict_2019.pkl')

# %%
len(decision2020)
# Out:
# 2213

# %%
doc = nlp(paper2020['Byg-wJSYDS']['content']['abstract'])

# %%
adjectives = {}
for tok in doc:
    print(tok.text, tok.pos_, tok.tag_)
    break
# Out:
# In ADP IN

# %%
accepted_papers = {}
rejected_papers = {}

acc_count = 0
rej_count = 0

# %%
for p in decision2020:
    if decision2020[p]['decision']['content']['decision'].strip().lower().startswith('accept'):
        acc_count += 1
        accepted_papers[decision2020[p]['decision']['forum']] = 1
    elif decision2020[p]['decision']['content']['decision'].strip().lower().startswith('reject'):
        rej_count += 1
        rejected_papers[decision2020[p]['decision']['forum']] = 1
    else:
        print(p)

# %%
print("Accepted papers 2020: ", acc_count)
print("Rejected papers 2020: ", rej_count)

rejected_papers = dict(random.sample(rejected_papers.items(), acc_count))
# Out:
# Accepted papers 2020:  687
# Rejected papers 2020:  1526

# %%
len(rejected_papers)
# Out:
# 687

# %%
adjectives = {}

for pid in accepted_papers:
    try:
        paper_abs = nlp(paper2020[pid]['content']['abstract'])
        for tok in paper_abs:
            if tok.pos_ == "ADJ":
                if tok.lemma_.strip() in adjectives:
                    adjectives[tok.lemma_.strip()][0] += 1
                else:
                    adjectives[tok.lemma_.strip()] = [1, 0]
    except Exception as ex:
        print(ex)

for pid in rejected_papers:
    try:
        paper_abs = nlp(paper2020[pid]['content']['abstract'])
        for tok in paper_abs:
            if tok.pos_ == "ADJ":
                if tok.lemma_.strip() in adjectives:
                    adjectives[tok.lemma_.strip()][1] += 1
                else:
                    adjectives[tok.lemma_.strip()] = [0, 1]
    except Exception as ex:
        print(ex)

# %%
list(adjectives.keys())[0:4]
# Out:
# ['unspecific', 'unscalable', 'metric', 'impractical']

# %%
adjectives['impractical']
# Out:
# [1, 2]

# %% [markdown]
# ### 2019 Data

# %%
accepted_papers = {}
rejected_papers = {}

acc_count = 0
rej_count = 0

for p in decision2019:
    if decision2019[p]['decision']['content']['recommendation'].strip().lower().startswith('accept'):
        acc_count += 1
        accepted_papers[decision2019[p]['decision']['forum']] = 1
    elif decision2019[p]['decision']['content']['recommendation'].strip().lower().startswith('reject'):
        rej_count += 1
        rejected_papers[decision2019[p]['decision']['forum']] = 1
    else:
        print(p)

# %%
print("Accepted papers 2019: ", acc_count)
print("Rejected papers 2019: ", rej_count)

rejected_papers = dict(random.sample(rejected_papers.items(), acc_count))
# Out:
# Accepted papers 2019:  502
# Rejected papers 2019:  917

# %%
for pid in accepted_papers:
    try:
        paper_abs = nlp(paper2019[pid]['content']['abstract'])
        for tok in paper_abs:
            if tok.pos_ == "ADJ":
                if tok.lemma_.strip() in adjectives:
                    adjectives[tok.lemma_.strip()][0] += 1
                else:
                    adjectives[tok.lemma_.strip()] = [1, 0]
    except Exception as ex:
        print(ex)

for pid in rejected_papers:
    try:
        paper_abs = nlp(paper2019[pid]['content']['abstract'])
        for tok in paper_abs:
            if tok.pos_ == "ADJ":
                if tok.lemma_.strip() in adjectives:
                    adjectives[tok.lemma_.strip()][1] += 1
                else:
                    adjectives[tok.lemma_.strip()] = [0, 1]
    except Exception as ex:
        print(ex)

# %%
adjectives['impractical']
# Out:
# [4, 5, 9, 1]

# %%
len(adjectives)
# Out:
# 2424

# %%
for k in adjectives:
    adjectives[k].append(adjectives[k][0]+adjectives[k][1])
    adjectives[k].append(abs(adjectives[k][0]-adjectives[k][1]))

# %%
sorted_adj_freq = sorted(adjectives.items(), key=lambda e: e[1][2], reverse=True)
sorted_adj_dist = sorted(adjectives.items(), key=lambda e: e[1][3], reverse=True)

# %%
sorted_adj_freq
# Out:
# [('neural', [810, 760, 1570, 50]),
#  ('-', [610, 611, 1221, 1]),
#  ('deep', [538, 544, 1082, 6]),
#  ('such', [529, 488, 1017, 41]),
#  ('new', [467, 420, 887, 47]),
#  ('adversarial', [383, 377, 760, 6]),
#  ('high', [348, 385, 733, 37]),
#  ('large', [361, 354, 715, 7]),
#  ('different', [304, 342, 646, 38]),
#  ('novel', [252, 262, 514, 10]),
#  ('many', [233, 232, 465, 1]),
#  ('low', [191, 241, 432, 50]),
#  ('simple', [221, 205, 426, 16]),
#  ('real', [202, 212, 414, 10]),
#  ('non', [222, 185, 407, 37]),
#  ('other', [181, 222, 403, 41]),
#  ('multi', [181, 195, 376, 14]),
#  ('generative', [153, 197, 350, 44]),
#  ('recent', [168, 180, 348, 12]),
#  ('standard', [179, 159, 338, 20]),
#  ('good', [163, 172, 335, 9]),
#  ('efficient', [193, 139, 332, 54]),
#  ('small', [159, 161, 320, 2]),
#  ('well', [145, 168, 313, 23]),
#  ('natural', [156, 157, 313, 1]),
#  ('few', [161, 148, 309, 13]),
#  ('several', [144, 159, 303, 15]),
#  ('multiple', [159, 129, 288, 30]),
#  ('linear', [162, 120, 282, 42]),
#  ('convolutional', [132, 149, 281, 17]),
#  ('complex', [166, 114, 280, 52]),
#  ('first', [151, 125, 276, 26]),
#  ('effective', [129, 147, 276, 18]),
#  ('previous', [154, 121, 275, 33]),
#  ('single', [124, 147, 271, 23]),
#  ('various', [137, 133, 270, 4]),
#  ('robust', [155, 112, 267, 43]),
#  ('theoretical', [140, 124, 264, 16]),
#  ('same', [135, 129, 264, 6]),
#  ('particular', [146, 112, 258, 34]),
#  ('stochastic', [126, 125, 251, 1]),
#  ('optimal', [132, 115, 247, 17]),
#  ('local', [124, 111, 235, 13]),
#  ('general', [127, 107, 234, 20]),
#  ('important', [113, 118, 231, 5]),
#  ('dimensional', [96, 130, 226, 34]),
#  ('human', [117, 107, 224, 10]),
#  ('able', [106, 116, 222, 10]),
#  ('specific', [106, 114, 220, 8]),
#  ('empirical', [133, 85, 218, 48]),
#  ('current', [101, 115, 216, 14]),
#  ('visual', [115, 98, 213, 17]),
#  ('continuous', [118, 92, 210, 26]),
#  ('available', [110, 98, 208, 12]),
#  ('experimental', [96, 112, 208, 16]),
#  ('computational', [99, 94, 193, 5]),
#  ('variational', [94, 94, 188, 0]),
#  ('prior', [91, 96, 187, 5]),
#  ('unsupervised', [100, 87, 187, 13]),
#  ('more', [101, 86, 187, 15]),
#  ('similar', [75, 110, 185, 35]),
#  ('sparse', [94, 90, 184, 4]),
#  ('significant', [91, 91, 182, 0]),
#  ('extensive', [93, 89, 182, 4]),
#  ('long', [85, 92, 177, 7]),
#  ('strong', [96, 80, 176, 16]),
#  ('random', [97, 78, 175, 19]),
#  ('global', [85, 82, 167, 3]),
#  ('popular', [85, 79, 164, 6]),
#  ('original', [62, 102, 164, 40]),
#  ('supervised', [72, 91, 163, 19]),
#  ('semantic', [77, 83, 160, 6]),
#  ('recurrent', [79, 80, 159, 1]),
#  ('wide', [81, 72, 153, 9]),
#  ('key', [80, 72, 152, 8]),
#  ('adaptive', [70, 81, 151, 11]),
#  ('common', [79, 71, 150, 8]),
#  ('possible', [74, 75, 149, 1]),
#  ('difficult', [68, 74, 142, 6]),
#  ('hierarchical', [77, 64, 141, 13]),
#  ('practical', [76, 65, 141, 11]),
#  ('fast', [82, 53, 135, 29]),
#  ('additional', [54, 80, 134, 26]),
#  ('most', [68, 64, 132, 4]),
#  ('free', [53, 79, 132, 26]),
#  ('hard', [52, 77, 129, 25]),
#  ('pre', [69, 59, 128, 10]),
#  ('temporal', [61, 64, 125, 3]),
#  ('synthetic', [60, 63, 123, 3]),
#  ('competitive', [60, 60, 120, 0]),
#  ('differentiable', [78, 41, 119, 37]),
#  ('accurate', [50, 67, 117, 17]),
#  ('discrete', [62, 51, 113, 11]),
#  ('critical', [61, 52, 113, 9]),
#  ('dynamic', [56, 51, 107, 5]),
#  ('useful', [57, 50, 107, 7]),
#  ('gradient', [61, 45, 106, 16]),
#  ('traditional', [52, 53, 105, 1]),
#  ('easy', [37, 68, 105, 31]),
#  ('conditional', [54, 51, 105, 3]),
#  ('node', [47, 58, 105, 11]),
#  ('learned', [55, 49, 104, 6]),
#  ('limited', [49, 51, 100, 2]),
#  ('unseen', [45, 54, 99, 9]),
#  ('binary', [50, 47, 97, 3]),
#  ('sequential', [50, 47, 97, 3]),
#  ('certain', [56, 41, 97, 15]),
#  ('dependent', [48, 47, 95, 1]),
#  ('powerful', [51, 43, 94, 8]),
#  ('wise', [41, 53, 94, 12]),
#  ('full', [49, 44, 93, 5]),
#  ('structured', [44, 48, 92, 4]),
#  ('diverse', [62, 30, 92, 32]),
#  ('realistic', [51, 40, 91, 11]),
#  ('3d', [54, 36, 90, 18]),
#  ('independent', [45, 45, 90, 0]),
#  ('challenging', [44, 46, 90, 2]),
#  ('promising', [50, 39, 89, 11]),
#  ('probabilistic', [44, 44, 88, 0]),
#  ('interpretable', [37, 51, 88, 14]),
#  ('comparable', [42, 45, 87, 3]),
#  ('relevant', [47, 40, 87, 7]),
#  ('second', [38, 49, 87, 11]),
#  ('bayesian', [43, 44, 87, 1]),
#  ('great', [44, 40, 84, 4]),
#  ('superior', [40, 43, 83, 3]),
#  ('future', [44, 39, 83, 5]),
#  ('predictive', [46, 37, 83, 9]),
#  ('spatial', [41, 39, 80, 2]),
#  ('individual', [44, 35, 79, 9]),
#  ('physical', [52, 27, 79, 25]),
#  ('average', [43, 36, 79, 7]),
#  ('metric', [30, 48, 78, 18]),
#  ('true', [34, 43, 77, 9]),
#  ('unlabeled', [34, 43, 77, 9]),
#  ('noisy', [30, 47, 77, 17]),
#  ('cross', [38, 39, 77, 1]),
#  ('open', [46, 31, 77, 15]),
#  ('classical', [41, 35, 76, 6]),
#  ('black', [45, 31, 76, 14]),
#  ('bad', [35, 41, 76, 6]),
#  ('main', [41, 34, 75, 7]),
#  ('arbitrary', [39, 35, 74, 4]),
#  ('negative', [27, 47, 74, 20]),
#  ('contextual', [33, 41, 74, 8]),
#  ('inductive', [46, 28, 74, 18]),
#  ('gaussian', [34, 40, 74, 6]),
#  ('conventional', [35, 38, 73, 3]),
#  ('entropy', [29, 44, 73, 15]),
#  ('capable', [40, 32, 72, 8]),
#  ('semi', [33, 39, 72, 6]),
#  ('nonlinear', [37, 34, 71, 3]),
#  ('unknown', [33, 38, 71, 5]),
#  ('invariant', [43, 28, 71, 15]),
#  ('meta', [38, 33, 71, 5]),
#  ('successful', [40, 30, 70, 10]),
#  ('less', [41, 29, 70, 12]),
#  ('explicit', [34, 35, 69, 1]),
#  ('short', [37, 32, 69, 5]),
#  ('relative', [35, 33, 68, 2]),
#  ('consistent', [38, 30, 68, 8]),
#  ('approximate', [36, 32, 68, 4]),
#  ('downstream', [40, 27, 67, 13]),
#  ('final', [27, 40, 67, 13]),
#  ('fundamental', [38, 29, 67, 9]),
#  ('stable', [37, 29, 66, 8]),
#  ('shot', [32, 34, 66, 2]),
#  ('statistical', [32, 34, 66, 2]),
#  ('expensive', [27, 39, 66, 12]),
#  ('objective', [24, 41, 65, 17]),
#  ('fine', [33, 32, 65, 1]),
#  ('numerical', [33, 30, 63, 3]),
#  ('sensitive', [40, 23, 63, 17]),
#  ('geometric', [41, 22, 63, 19]),
#  ('little', [35, 28, 63, 7]),
#  ('online', [31, 31, 62, 0]),
#  ('major', [30, 32, 62, 2]),
#  ('agent', [46, 16, 62, 30]),
#  ('modern', [37, 25, 62, 12]),
#  ('further', [29, 33, 62, 4]),
#  ('crucial', [33, 29, 62, 4]),
#  ('intrinsic', [32, 30, 62, 2]),
#  ('meaningful', [22, 40, 62, 18]),
#  ('variable', [44, 18, 62, 26]),
#  ('initial', [33, 28, 61, 5]),
#  ('artificial', [35, 26, 61, 9]),
#  ('mutual', [31, 30, 61, 1]),
#  ('discriminative', [24, 37, 61, 13]),
#  ('structural', [47, 13, 60, 34]),
#  ('applicable', [35, 25, 60, 10]),
#  ('universal', [28, 32, 60, 4]),
#  ('joint', [27, 33, 60, 6]),
#  ('dynamical', [32, 27, 59, 5]),
#  ('potential', [26, 33, 59, 7]),
#  ('auxiliary', [21, 38, 59, 17]),
#  ('maximum', [32, 27, 59, 5]),
#  ('flexible', [32, 26, 58, 6]),
#  ('only', [29, 29, 58, 0]),
#  ('past', [21, 37, 58, 16]),
#  ('positive', [21, 37, 58, 16]),
#  ('poor', [28, 30, 58, 2]),
#  ('finite', [32, 26, 58, 6]),
#  ('scalable', [36, 22, 58, 14]),
#  ('continual', [27, 30, 57, 3]),
#  ('early', [26, 31, 57, 5]),
#  ('implicit', [23, 33, 56, 10]),
#  ('essential', [21, 35, 56, 14]),
#  ('agnostic', [19, 37, 56, 18]),
#  ('aware', [24, 32, 56, 8]),
#  ('smooth', [32, 24, 56, 8]),
#  ('parallel', [25, 31, 56, 6]),
#  ('Most', [24, 31, 55, 7]),
#  ('internal', [25, 30, 55, 5]),
#  ('spectral', [26, 29, 55, 3]),
#  ('necessary', [23, 32, 55, 9]),
#  ('close', [28, 27, 55, 1]),
#  ('suitable', [26, 28, 54, 2]),
#  ('active', [23, 31, 54, 8]),
#  ('expressive', [27, 27, 54, 0]),
#  ('posterior', [32, 21, 53, 11]),
#  ('rich', [28, 25, 53, 3]),
#  ('dense', [30, 23, 53, 7]),
#  ('underlying', [33, 19, 52, 14]),
#  ('direct', [27, 25, 52, 2]),
#  ('corresponding', [25, 26, 51, 1]),
#  ('batch', [25, 25, 50, 0]),
#  ('compact', [22, 28, 50, 6]),
#  ('constant', [29, 21, 50, 8]),
#  ('raw', [25, 25, 50, 0]),
#  ('much', [26, 24, 50, 2]),
#  ('clean', [28, 22, 50, 6]),
#  ('stationary', [36, 13, 49, 23]),
#  ('simulated', [24, 25, 49, 1]),
#  ('entire', [24, 25, 49, 1]),
#  ('exact', [27, 22, 49, 5]),
#  ('alternative', [30, 19, 49, 11]),
#  ('mean', [21, 27, 48, 6]),
#  ('audio', [25, 23, 48, 2]),
#  ('iterative', [27, 21, 48, 6]),
#  ('comprehensive', [23, 25, 48, 2]),
#  ('interesting', [22, 25, 47, 3]),
#  ('compositional', [37, 9, 46, 28]),
#  ('due', [27, 19, 46, 8]),
#  ('substantial', [21, 24, 45, 3]),
#  ('quantitative', [24, 21, 45, 3]),
#  ('causal', [18, 26, 44, 8]),
#  ('informative', [22, 22, 44, 0]),
#  ('soft', [25, 19, 44, 6]),
#  ('euclidean', [25, 19, 44, 6]),
#  ('benchmark', [25, 19, 44, 6]),
#  ('top', [18, 26, 44, 8]),
#  ('relational', [19, 24, 43, 5]),
#  ('residual', [22, 21, 43, 1]),
#  ('catastrophic', [21, 22, 43, 1]),
#  ('tight', [23, 20, 43, 3]),
#  ('like', [20, 23, 43, 3]),
#  ('autoregressive', [27, 16, 43, 11]),
#  ('forward', [21, 21, 42, 0]),
#  ('distinct', [26, 16, 42, 10]),
#  ('typical', [24, 18, 42, 6]),
#  ('separate', [24, 18, 42, 6]),
#  ('deterministic', [25, 17, 42, 8]),
#  ('sufficient', [22, 19, 41, 3]),
#  ('automatic', [18, 23, 41, 5]),
#  ('vulnerable', [18, 23, 41, 5]),
#  ('broad', [26, 14, 40, 12]),
#  ('slow', [21, 19, 40, 2]),
#  ('generic', [23, 17, 40, 6]),
#  ('biological', [16, 24, 40, 8]),
#  ('partial', [21, 19, 40, 2]),
#  ('near', [23, 16, 39, 7]),
#  ('super', [18, 21, 39, 3]),
#  ('autonomous', [22, 17, 39, 5]),
#  ('minimal', [16, 22, 38, 6]),
#  ('whole', [18, 20, 38, 2]),
#  ('normal', [19, 19, 38, 0]),
#  ('sub', [19, 19, 38, 0]),
#  ('central', [20, 17, 37, 3]),
#  ('theoretic', [17, 20, 37, 3]),
#  ('convex', [17, 20, 37, 3]),
#  ('impressive', [19, 18, 37, 1]),
#  ('external', [17, 20, 37, 3]),
#  ('overall', [11, 26, 37, 15]),
#  ('special', [21, 15, 36, 6]),
#  ('mathematical', [17, 19, 36, 2]),
#  ('next', [18, 18, 36, 0]),
#  ('parameter', [21, 15, 36, 6]),
#  ('basic', [18, 18, 36, 0]),
#  ('intuitive', [14, 22, 36, 8]),
#  ('unified', [18, 18, 36, 0]),
#  ('present', [14, 22, 36, 8]),
#  ('related', [19, 17, 36, 2]),
#  ('systematic', [18, 18, 36, 0]),
#  ('equivariant', [25, 10, 35, 15]),
#  ('symbolic', [25, 10, 35, 15]),
#  ('own', [15, 20, 35, 5]),
#  ('backward', [19, 16, 35, 3]),
#  ('reliable', [24, 11, 35, 13]),
#  ('ensemble', [19, 16, 35, 3]),
#  ('clear', [15, 20, 35, 5]),
#  ('desirable', [17, 18, 35, 1]),
#  ('intermediate', [20, 14, 34, 6]),
#  ('formal', [21, 13, 34, 8]),
#  ('lifelong', [15, 19, 34, 4]),
#  ('appropriate', [13, 20, 33, 7]),
#  ('trivial', [18, 15, 33, 3]),
#  ('mobile', [16, 17, 33, 1]),
#  ('hybrid', [12, 21, 33, 9]),
#  ('modal', [17, 16, 33, 1]),
#  ('abstract', [15, 18, 33, 3]),
#  ('plausible', [16, 16, 32, 0]),
#  ('training', [18, 14, 32, 4]),
#  ('architectural', [19, 13, 32, 6]),
#  ('dual', [16, 16, 32, 0]),
#  ('differential', [16, 16, 32, 0]),
#  ('medical', [13, 19, 32, 6]),
#  ('functional', [22, 10, 32, 12]),
#  ('shallow', [21, 10, 31, 11]),
#  ('combinatorial', [16, 15, 31, 1]),
#  ('mini', [17, 14, 31, 3]),
#  ('weak', [17, 14, 31, 3]),
#  ('robotic', [19, 12, 31, 7]),
#  ('provable', [20, 11, 31, 9]),
#  ('representational', [14, 16, 30, 2]),
#  ('tabular', [19, 11, 30, 8]),
#  ('total', [17, 13, 30, 4]),
#  ('remarkable', [13, 17, 30, 4]),
#  ('primary', [21, 9, 30, 12]),
#  ('qualitative', [15, 15, 30, 0]),
#  ('equivalent', [20, 10, 30, 10]),
#  ('costly', [20, 10, 30, 10]),
#  ('task', [18, 12, 30, 6]),
#  ('considerable', [18, 12, 30, 6]),
#  ('hidden', [13, 17, 30, 4]),
#  ('unique', [21, 9, 30, 12]),
#  ('textual', [9, 20, 29, 11]),
#  ('huge', [12, 17, 29, 5]),
#  ('manual', [17, 12, 29, 5]),
#  ('precise', [21, 8, 29, 13]),
#  ('latter', [12, 17, 29, 5]),
#  ('randomized', [16, 13, 29, 3]),
#  ('complete', [17, 12, 29, 5]),
#  ('invertible', [8, 20, 28, 12]),
#  ('orthogonal', [17, 11, 28, 6]),
#  ('improved', [10, 18, 28, 8]),
#  ('feedforward', [15, 13, 28, 2]),
#  ('above', [14, 14, 28, 0]),
#  ('surrogate', [13, 15, 28, 2]),
#  ('biased', [8, 20, 28, 12]),
#  ('complementary', [12, 16, 28, 4]),
#  ('expert', [15, 12, 27, 3]),
#  ('boundary', [7, 20, 27, 13]),
#  ('molecular', [5, 22, 27, 17]),
#  ('trainable', [15, 12, 27, 3]),
#  ('regular', [9, 18, 27, 9]),
#  ('inherent', [15, 12, 27, 3]),
#  ('marginal', [16, 11, 27, 5]),
#  ('unbiased', [18, 9, 27, 9]),
#  ('asynchronous', [13, 13, 26, 0]),
#  ('uniform', [14, 12, 26, 2]),
#  ('parametric', [17, 9, 26, 8]),
#  ('last', [14, 12, 26, 2]),
#  ('least', [11, 15, 26, 4]),
#  ('incremental', [12, 14, 26, 2]),
#  ('correct', [12, 14, 26, 2]),
#  ('absolute', [16, 9, 25, 7]),
#  ('equal', [12, 13, 25, 1]),
#  ('classic', [14, 11, 25, 3]),
#  ('behavioral', [15, 10, 25, 5]),
#  ('riemannian', [12, 13, 25, 1]),
#  ('\\em', [15, 10, 25, 5]),
#  ('tractable', [14, 11, 25, 3]),
#  ('likely', [15, 10, 25, 5]),
#  ('linguistic', [16, 9, 25, 7]),
#  ('public', [7, 17, 24, 10]),
#  ('beneficial', [12, 12, 24, 0]),
#  ('counterfactual', [13, 11, 24, 2]),
#  ('robustness', [13, 11, 24, 2]),
#  ('observed', [12, 12, 24, 0]),
#  ('heuristic', [9, 15, 24, 6]),
#  ('exponential', [13, 11, 24, 2]),
#  ('upper', [11, 13, 24, 2]),
#  ('former', [9, 15, 24, 6]),
#  ('2d', [16, 8, 24, 8]),
#  ('controllable', [13, 11, 24, 2]),
#  ('baseline', [8, 16, 24, 8]),
#  ('extra', [11, 13, 24, 2]),
#  ('normalized', [15, 9, 24, 6]),
#  ('surprising', [15, 9, 24, 6]),
#  ('hyperbolic', [14, 10, 24, 4]),
#  ('feasible', [12, 11, 23, 1]),
#  ('static', [15, 8, 23, 7]),
#  ('topological', [14, 9, 23, 5]),
#  ('manifold', [9, 14, 23, 5]),
#  ('off', [13, 10, 23, 3]),
#  ('negligible', [10, 13, 23, 3]),
#  ('principled', [12, 11, 23, 1]),
#  ('episodic', [10, 12, 22, 2]),
#  ('inefficient', [11, 11, 22, 0]),
#  ('coherent', [14, 8, 22, 6]),
#  ('asymptotic', [14, 8, 22, 6]),
#  ('representative', [11, 11, 22, 0]),
#  ('polynomial', [8, 14, 22, 6]),
#  ('proper', [8, 14, 22, 6]),
#  ('directional', [10, 12, 22, 2]),
#  ('greedy', [12, 10, 22, 2]),
#  ('prone', [8, 13, 21, 5]),
#  ('private', [7, 14, 21, 7]),
#  ('constrained', [6, 15, 21, 9]),
#  ('lingual', [8, 13, 21, 5]),
#  ('perceptual', [11, 10, 21, 1]),
#  ('selective', [3, 18, 21, 15]),
#  ('careful', [11, 10, 21, 1]),
#  ('logical', [15, 6, 21, 9]),
#  ('interactive', [10, 11, 21, 1]),
#  ('intensive', [7, 14, 21, 7]),
#  ('arithmetic', [11, 10, 21, 1]),
#  ('algorithmic', [14, 7, 21, 7]),
#  ('fair', [14, 7, 21, 7]),
#  ('trained', [10, 11, 21, 1]),
#  ('quadratic', [14, 7, 21, 7]),
#  ('detailed', [9, 11, 20, 2]),
#  ('rigorous', [10, 10, 20, 0]),
#  ('white', [9, 11, 20, 2]),
#  ('evolutionary', [3, 17, 20, 14]),
#  ('insufficient', [12, 8, 20, 4]),
#  ('primitive', [16, 4, 20, 12]),
#  ('mixed', [12, 8, 20, 4]),
#  ('observable', [11, 9, 20, 2]),
#  ('massive', [7, 13, 20, 6]),
#  ('unstable', [10, 10, 20, 0]),
#  ('class', [10, 10, 20, 0]),
#  ('numerous', [7, 13, 20, 6]),
#  ('learnable', [10, 10, 20, 0]),
#  ('multilingual', [14, 6, 20, 8]),
#  ('double', [8, 12, 20, 4]),
#  ('inter', [8, 12, 20, 4]),
#  ('modular', [12, 8, 20, 4]),
#  ('complicated', [13, 6, 19, 7]),
#  ('big', [12, 7, 19, 5]),
#  ('mild', [13, 6, 19, 7]),
#  ('specialized', [9, 10, 19, 1]),
#  ('proximal', [6, 13, 19, 7]),
#  ('identical', [9, 10, 19, 1]),
#  ('federated', [13, 6, 19, 7]),
#  ('suboptimal', [9, 10, 19, 1]),
#  ('syntactic', [14, 5, 19, 9]),
#  ('scale', [10, 9, 19, 1]),
#  ('extreme', [9, 9, 18, 0]),
#  ('perfect', [12, 6, 18, 6]),
#  ('weighted', [6, 12, 18, 6]),
#  ('minimum', [8, 10, 18, 2]),
#  ('intractable', [12, 6, 18, 6]),
#  ('sharp', [10, 8, 18, 2]),
#  ('intriguing', [11, 7, 18, 4]),
#  ('transferable', [10, 8, 18, 2]),
#  ('collaborative', [9, 9, 18, 0]),
#  ('atari', [10, 8, 18, 2]),
#  ('thorough', [8, 10, 18, 2]),
#  ('unable', [8, 10, 18, 2]),
#  ('heterogeneous', [7, 10, 17, 3]),
#  ('amenable', [12, 5, 17, 7]),
#  ('distributional', [8, 9, 17, 1]),
#  ('intelligent', [10, 7, 17, 3]),
#  ('cooperative', [13, 4, 17, 9]),
#  ('english', [2, 15, 17, 13]),
#  ('observational', [11, 6, 17, 5]),
#  ('valid', [11, 6, 17, 5]),
#  ('disentangled', [10, 7, 17, 3]),
#  ('enough', [9, 8, 17, 1]),
#  ('advanced', [8, 9, 17, 1]),
#  ('infinite', [11, 5, 16, 6]),
#  ('dataset', [7, 9, 16, 2]),
#  ('german', [10, 6, 16, 4]),
#  ('layer', [9, 7, 16, 2]),
#  ('fake', [5, 11, 16, 6]),
#  ('offline', [6, 10, 16, 4]),
#  ('unlabelled', [8, 8, 16, 0]),
#  ('back', [8, 8, 16, 0]),
#  ('shared', [9, 7, 16, 2]),
#  ('contrastive', [11, 5, 16, 6]),
#  ('net', [10, 6, 16, 4]),
#  ('progressive', [5, 11, 16, 6]),
#  ('receptive', [8, 8, 16, 0]),
#  ('view', [4, 12, 16, 8]),
#  ('virtual', [9, 7, 16, 2]),
#  ('scarce', [7, 9, 16, 2]),
#  ('spurious', [13, 3, 16, 10]),
#  ('unstructured', [8, 8, 16, 0]),
#  ('cumulative', [8, 7, 15, 1]),
#  ('uncertain', [10, 5, 15, 5]),
#  ('straightforward', [4, 11, 15, 7]),
#  ('width', [9, 6, 15, 3]),
#  ('inverse', [4, 11, 15, 7]),
#  ('old', [4, 11, 15, 7]),
#  ('dominant', [6, 9, 15, 3]),
#  ('anomalous', [6, 9, 15, 3]),
#  ('sensory', [6, 9, 15, 3]),
#  ('ordinary', [8, 7, 15, 1]),
#  ('decentralized', [6, 9, 15, 3]),
#  ('graphical', [10, 5, 15, 5]),
#  ('vast', [8, 7, 15, 1]),
#  ('accelerated', [4, 11, 15, 7]),
#  ('object', [10, 5, 15, 5]),
#  ('hop', [8, 7, 15, 1]),
#  ('categorical', [8, 7, 15, 1]),
#  ('irrelevant', [5, 10, 15, 5]),
#  ('sophisticated', [8, 6, 14, 2]),
#  ('skip', [10, 4, 14, 6]),
#  ('lightweight', [8, 6, 14, 2]),
#  ('flat', [5, 9, 14, 4]),
#  ('dictionary', [11, 3, 14, 8]),
#  ('incomplete', [9, 5, 14, 4]),
#  ('musical', [11, 3, 14, 8]),
#  ('impossible', [9, 5, 14, 4]),
#  ('reasonable', [5, 9, 14, 4]),
#  ('outperform', [12, 2, 14, 10]),
#  ('incorrect', [6, 8, 14, 2]),
#  ('rapid', [8, 6, 14, 2]),
#  ('viable', [7, 7, 14, 0]),
#  ('domain', [9, 5, 14, 4]),
#  ('naive', [5, 9, 14, 4]),
#  ('spherical', [10, 4, 14, 6]),
#  ('core', [6, 8, 14, 2]),
#  ('symmetric', [11, 3, 14, 8]),
#  ('smoothness', [8, 6, 14, 2]),
#  ('ternary', [5, 9, 14, 4]),
#  ('unclear', [10, 4, 14, 6]),
#  ('ubiquitous', [8, 6, 14, 2]),
#  ('principal', [4, 10, 14, 6]),
#  ('intra', [3, 11, 14, 8]),
#  ('interested', [4, 9, 13, 5]),
#  ('analytical', [6, 7, 13, 1]),
#  ('bilingual', [4, 9, 13, 5]),
#  ('blind', [7, 6, 13, 1]),
#  ('attribute', [2, 11, 13, 9]),
#  ('reproducible', [8, 5, 13, 3]),
#  ('favorable', [4, 9, 13, 5]),
#  ('actual', [7, 6, 13, 1]),
#  ('token', [10, 3, 13, 7]),
#  ('prohibitive', [5, 8, 13, 3]),
#  ('strict', [9, 4, 13, 5]),
#  ('generalized', [5, 8, 13, 3]),
#  ('analytic', [10, 3, 13, 7]),
#  ('optimistic', [11, 2, 13, 9]),
#  ('chemical', [4, 9, 13, 5]),
#  ('inner', [8, 5, 13, 3]),
#  ('susceptible', [7, 6, 13, 1]),
#  ('unnecessary', [6, 6, 12, 0]),
#  ('signal', [8, 4, 12, 4]),
#  ('restrictive', [6, 6, 12, 0]),
#  ('co', [7, 5, 12, 2]),
#  ('imperceptible', [6, 6, 12, 0]),
#  ('excessive', [5, 7, 12, 2]),
#  ('quantum', [4, 8, 12, 4]),
#  ('attentive', [6, 6, 12, 0]),
#  ('logarithmic', [8, 4, 12, 4]),
#  ('third', [7, 5, 12, 2]),
#  ('closed', [6, 6, 12, 0]),
#  ('preliminary', [6, 6, 12, 0]),
#  ('wrong', [6, 6, 12, 0]),
#  ('historical', [7, 5, 12, 2]),
#  ('sound', [7, 5, 12, 2]),
#  ('unexplored', [9, 3, 12, 6]),
#  ('tremendous', [6, 6, 12, 0]),
#  ('lexical', [8, 4, 12, 4]),
#  ('n', [4, 8, 12, 4]),
#  ('subsequent', [6, 6, 12, 0]),
#  ('unobserved', [7, 5, 12, 2]),
#  ('outlier', [4, 8, 12, 4]),
#  ('analogous', [5, 7, 12, 2]),
#  ('separable', [2, 10, 12, 8]),
#  ('homogeneous', [6, 5, 11, 1]),
#  ('excellent', [7, 4, 11, 3]),
#  ('rare', [5, 6, 11, 1]),
#  ('undesirable', [5, 6, 11, 1]),
#  ('safe', [3, 8, 11, 5]),
#  ('atomic', [6, 5, 11, 1]),
#  ('bi', [3, 8, 11, 5]),
#  ('concrete', [7, 4, 11, 3]),
#  ('predictable', [9, 2, 11, 7]),
#  ('boolean', [5, 6, 11, 1]),
#  ('spatiotemporal', [6, 5, 11, 1]),
#  ('narrow', [5, 6, 11, 1]),
#  ('existing', [5, 6, 11, 1]),
#  ('canonical', [6, 5, 11, 1]),
#  ('cheap', [8, 3, 11, 5]),
#  ('helpful', [3, 8, 11, 5]),
#  ('facial', [4, 7, 11, 3]),
#  ('valuable', [3, 8, 11, 5]),
#  ('step', [0, 11, 11, 11]),
#  ('cifar-10', [7, 4, 11, 3]),
#  ('aforementioned', [7, 4, 11, 3]),
#  ('emergent', [5, 6, 11, 1]),
#  ('unconditional', [5, 6, 11, 1]),
#  ('hamiltonian', [10, 1, 11, 9]),
#  ('convincing', [5, 6, 11, 1]),
#  ('respective', [4, 7, 11, 3]),
#  ('centralized', [7, 3, 10, 4]),
#  ('prominent', [8, 2, 10, 6]),
#  ('post', [6, 4, 10, 2]),
#  ('additive', [4, 6, 10, 2]),
#  ('contrary', [4, 6, 10, 2]),
#  ('bidirectional', [3, 7, 10, 4]),
#  ('svhn', [4, 6, 10, 2]),
#  ('compressive', [4, 6, 10, 2]),
#  ('scalar', [3, 7, 10, 4]),
#  ('versatile', [6, 4, 10, 2]),
#  ('simultaneous', [5, 5, 10, 0]),
#  ('singular', [7, 3, 10, 4]),
#  ('synchronous', [7, 3, 10, 4]),
#  ('ambiguous', [7, 3, 10, 4]),
#  ('fit', [2, 8, 10, 6]),
#  ('asymmetric', [6, 4, 10, 2]),
#  ('social', [6, 4, 10, 2]),
#  ('pure', [4, 6, 10, 2]),
#  ('logistic', [7, 3, 10, 4]),
#  ('transductive', [8, 2, 10, 6]),
#  ('suited', [5, 5, 10, 0]),
#  ('aligned', [4, 6, 10, 2]),
#  ('connected', [5, 5, 10, 0]),
#  ('technical', [4, 6, 10, 2]),
#  ('imperfect', [2, 8, 10, 6]),
#  ('counter', [3, 7, 10, 4]),
#  ('abundant', [5, 5, 10, 0]),
#  ('coarse', [6, 4, 10, 2]),
#  ('compute', [8, 2, 10, 6]),
#  ('label', [3, 7, 10, 4]),
#  ('exploratory', [8, 2, 10, 6]),
#  ('false', [4, 6, 10, 2]),
#  ('impractical', [4, 5, 9, 1]),
#  ('lazy', [3, 6, 9, 3]),
#  ('severe', [1, 8, 9, 7]),
#  ('explainable', [1, 8, 9, 7]),
#  ('indispensable', [2, 7, 9, 5]),
#  ('multiplicative', [8, 1, 9, 7]),
#  ('diagnostic', [6, 3, 9, 3]),
#  ('unconstrained', [5, 4, 9, 1]),
#  ('malicious', [3, 6, 9, 3]),
#  ('appealing', [4, 5, 9, 1]),
#  ('genetic', [5, 4, 9, 1]),
#  ('tiny', [5, 4, 9, 1]),
#  ('pretrained', [6, 3, 9, 3]),
#  ('staleness', [8, 1, 9, 7]),
#  ('scientific', [4, 5, 9, 1]),
#  ('zeroth', [6, 3, 9, 3]),
#  ('ideal', [4, 5, 9, 1]),
#  ('unwanted', [5, 4, 9, 1]),
#  ('extended', [2, 7, 9, 5]),
#  ('recursive', [3, 6, 9, 3]),
#  ('unexpected', [9, 0, 9, 9]),
#  ('tangent', [6, 3, 9, 3]),
#  ('proportional', [6, 3, 9, 3]),
#  ('usual', [2, 7, 9, 5]),
#  ('synaptic', [4, 5, 9, 1]),
#  ('longitudinal', [0, 9, 9, 9]),
#  ('normalizing', [2, 6, 8, 4]),
#  ('comparative', [5, 3, 8, 2]),
#  ('benign', [5, 3, 8, 2]),
#  ('satisfactory', [4, 4, 8, 0]),
#  ('heavy', [2, 6, 8, 4]),
#  ('side', [7, 1, 8, 6]),
#  ('unlikely', [3, 5, 8, 2]),
#  ('prevalent', [7, 1, 8, 6]),
#  ('lagrangian', [5, 3, 8, 2]),
#  ('warm', [0, 8, 8, 8]),
#  ('serious', [1, 7, 8, 6]),
#  ('confident', [5, 3, 8, 2]),
#  ('infeasible', [4, 4, 8, 0]),
#  ('balanced', [6, 2, 8, 4]),
#  ('exciting', [3, 5, 8, 2]),
#  ('cognitive', [2, 6, 8, 4]),
#  ('maximal', [2, 6, 8, 4]),
#  ('widespread', [4, 4, 8, 0]),
#  ('secondary', [3, 5, 8, 2]),
#  ('generalizable', [4, 4, 8, 0]),
#  ('straight', [6, 2, 8, 4]),
#  ('elusive', [4, 4, 8, 0]),
#  ('associative', [5, 3, 8, 2]),
#  ('sample', [3, 5, 8, 2]),
#  ('primal', [6, 2, 8, 4]),
#  ('prototypical', [2, 6, 8, 4]),
#  ('conversational', [5, 3, 8, 2]),
#  ('frequent', [4, 4, 8, 0]),
#  ('theorem', [2, 6, 8, 4]),
#  ('discontinuous', [5, 3, 8, 2]),
#  ('salient', [7, 1, 8, 6]),
#  ('clinical', [0, 8, 8, 8]),
#  ('compelling', [5, 3, 8, 2]),
#  ('simplified', [2, 6, 8, 4]),
#  ('abstractive', [2, 6, 8, 4]),
#  ('fitting', [4, 4, 8, 0]),
#  ('redundant', [7, 1, 8, 6]),
#  ('half', [1, 7, 8, 6]),
#  ('successive', [3, 4, 7, 1]),
#  ('concise', [2, 5, 7, 3]),
#  ('monolingual', [3, 4, 7, 1]),
#  ('inconsistent', [2, 5, 7, 3]),
#  ('resultant', [5, 2, 7, 3]),
#  ('specified', [4, 3, 7, 1]),
#  ('nonparametric', [2, 5, 7, 3]),
#  ('sampled', [3, 4, 7, 1]),
#  ('rigid', [5, 2, 7, 3]),
#  ('integral', [5, 2, 7, 3]),
#  ('subject', [2, 5, 7, 3]),
#  ('coordinate', [5, 2, 7, 3]),
#  ('resilient', [3, 4, 7, 1]),
#  ('electronic', [1, 6, 7, 5]),
#  ('motivated', [3, 4, 7, 1]),
#  ('elegant', [3, 4, 7, 1]),
#  ('industrial', [3, 4, 7, 1]),
#  ('divergent', [4, 3, 7, 1]),
#  ('heteroscedastic', [3, 4, 7, 1]),
#  ('varied', [2, 5, 7, 3]),
#  ('contemporary', [4, 3, 7, 1]),
#  ('environmental', [2, 5, 7, 3]),
#  ('handwritten', [3, 4, 7, 1]),
#  ('unrelated', [4, 3, 7, 1]),
#  ('certified', [5, 2, 7, 3]),
#  ('attractive', [3, 4, 7, 1]),
#  ('iid', [3, 4, 7, 1]),
#  ('unrealistic', [3, 4, 7, 1]),
#  ('jacobian', [5, 2, 7, 3]),
#  ('smoothed', [5, 2, 7, 3]),
#  ('passive', [3, 4, 7, 1]),
#  ('unbounded', [4, 3, 7, 1]),
#  ('localized', [5, 2, 7, 3]),
#  ('solid', [3, 4, 7, 1]),
#  ('median', [4, 3, 7, 1]),
#  ('convergence', [3, 4, 7, 1]),
#  ('late', [1, 6, 7, 5]),
#  ('plain', [3, 4, 7, 1]),
#  ('sensible', [2, 5, 7, 3]),
#  ('lossy', [5, 2, 7, 3]),
#  ('outstanding', [1, 6, 7, 5]),
#  ('distant', [2, 5, 7, 3]),
#  ('enhanced', [3, 4, 7, 1]),
#  ('problematic', [3, 4, 7, 1]),
#  ('imaginary', [1, 6, 7, 5]),
#  ('cold', [1, 6, 7, 5]),
#  ('predefined', [4, 3, 7, 1]),
#  ('lossless', [7, 0, 7, 7]),
#  ('conceptual', [4, 3, 7, 1]),
#  ('responsible', [4, 3, 7, 1]),
#  ('unifying', [4, 3, 7, 1]),
#  ('hungry', [3, 4, 7, 1]),
#  ('processing', [4, 3, 7, 1]),
#  ('incoming', [2, 4, 6, 2]),
#  ('subgoal', [3, 3, 6, 0]),
#  ('markovian', [2, 4, 6, 2]),
#  ('obtained', [3, 3, 6, 0]),
#  ('reusable', [2, 4, 6, 2]),
#  ('inputs', [1, 5, 6, 4]),
#  ('linearized', [5, 1, 6, 4]),
#  ('defensive', [2, 4, 6, 2]),
#  ('expected', [4, 2, 6, 2]),
#  ('cryo', [6, 0, 6, 6]),
#  ('light', [4, 2, 6, 2]),
#  ('drastic', [3, 3, 6, 0]),
#  ('friendly', [4, 2, 6, 2]),
#  ('polar', [1, 5, 6, 4]),
#  ('derivative', [2, 4, 6, 2]),
#  ('life', [0, 6, 6, 6]),
#  ('squared', [3, 3, 6, 0]),
#  ('siamese', [0, 6, 6, 6]),
#  ('executable', [4, 2, 6, 2]),
#  ('indistinguishable', [3, 3, 6, 0]),
#  ('latency', [4, 2, 6, 2]),
#  ('dissimilar', [3, 3, 6, 0]),
#  ('targeted', [1, 5, 6, 4]),
#  ('steady', [3, 3, 6, 0]),
#  ('zero', [5, 1, 6, 4]),
#  ('periodic', [5, 1, 6, 4]),
#  ('relaxed', [3, 3, 6, 0]),
#  ('linearly', [3, 3, 6, 0]),
#  ('optical', [2, 4, 6, 2]),
#  ('accessible', [4, 2, 6, 2]),
#  ('logged', [4, 2, 6, 2]),
#  ('cache', [1, 5, 6, 4]),
#  ('restricted', [5, 1, 6, 4]),
#  ('conservative', [4, 2, 6, 2]),
#  ('reduced', [4, 2, 6, 2]),
#  ('diagonal', [2, 4, 6, 2]),
#  ('optimized', [2, 4, 6, 2]),
#  ('speaker', [2, 4, 6, 2]),
#  ('modest', [4, 2, 6, 2]),
#  ('demonstrated', [5, 1, 6, 4]),
#  ('holistic', [3, 3, 6, 0]),
#  ('later', [0, 6, 6, 6]),
#  ('harmful', [1, 5, 6, 4]),
#  ('unprecedented', [2, 4, 6, 2]),
#  ('sized', [3, 3, 6, 0]),
#  ('turbulent', [0, 6, 6, 6]),
#  ('d', [4, 2, 6, 2]),
#  ('harmonic', [4, 2, 6, 2]),
#  ('unbalanced', [4, 2, 6, 2]),
#  ('compressed', [6, 0, 6, 6]),
#  ('approximated', [2, 4, 6, 2]),
#  ('inaccurate', [2, 4, 6, 2]),
#  ('exclusive', [4, 2, 6, 2]),
#  ('insensitive', [4, 2, 6, 2]),
#  ('decoder', [2, 4, 6, 2]),
#  ('gradual', [2, 4, 6, 2]),
#  ('defective', [0, 6, 6, 6]),
#  ('vital', [3, 3, 6, 0]),
#  ('nice', [4, 2, 6, 2]),
#  ('angular', [3, 3, 6, 0]),
#  ('monocular', [3, 3, 6, 0]),
#  ('scaling', [3, 3, 6, 0]),
#  ('inappropriate', [5, 1, 6, 4]),
#  ('consecutive', [0, 6, 6, 6]),
#  ('variant', [1, 4, 5, 3]),
#  ('procedural', [5, 0, 5, 5]),
#  ('subjective', [2, 3, 5, 1]),
#  ('humanoid', [3, 2, 5, 1]),
#  ('explanatory', [5, 0, 5, 5]),
#  ('unusual', [2, 3, 5, 1]),
#  ('solar', [5, 0, 5, 5]),
#  ('decent', [2, 3, 5, 1]),
#  ('leveraged', [4, 1, 5, 3]),
#  ('identifiable', [3, 2, 5, 1]),
#  ('distributed', [4, 1, 5, 3]),
#  ('level', [3, 2, 5, 1]),
#  ('miniimagenet', [1, 4, 5, 3]),
#  ('indirect', [4, 1, 5, 3]),
#  ('navigational', [2, 3, 5, 1]),
#  ('monotonic', [4, 1, 5, 3]),
#  ('induced', [4, 1, 5, 3]),
#  ('known', [3, 2, 5, 1]),
#  ('chinese', [1, 4, 5, 3]),
#  ('moderate', [0, 5, 5, 5]),
#  ('repetitive', [4, 1, 5, 3]),
#  ('phoneme', [4, 1, 5, 3]),
#  ('unsatisfactory', [2, 3, 5, 1]),
#  ('ineffective', [4, 1, 5, 3]),
#  ('de', [2, 3, 5, 1]),
#  ('probable', [2, 3, 5, 1]),
#  ('supervisory', [4, 1, 5, 3]),
#  ('pervasive', [2, 3, 5, 1]),
#  ('unisensory', [0, 5, 5, 5]),
#  ('sentence', [4, 1, 5, 3]),
#  ('quantized', [4, 1, 5, 3]),
#  ('morphological', [2, 3, 5, 1]),
#  ('right', [2, 3, 5, 1]),
#  ('composite', [3, 2, 5, 1]),
#  ('rewarding', [4, 1, 5, 3]),
#  ('dedicated', [3, 2, 5, 1]),
#  ('personalized', [3, 2, 5, 1]),
#  ('scaled', [0, 5, 5, 5]),
#  ('subtle', [4, 1, 5, 3]),
#  ('superficial', [4, 1, 5, 3]),
#  ('unintended', [1, 4, 5, 3]),
#  ('decomposable', [3, 2, 5, 1]),
#  ('algebraic', [3, 2, 5, 1]),
#  ('professional', [2, 3, 5, 1]),
#  ('stale', [3, 2, 5, 1]),
#  ('imbalanced', [2, 3, 5, 1]),
#  ('elementary', [3, 2, 5, 1]),
#  ('fractional', [2, 3, 5, 1]),
#  ('abductive', [5, 0, 5, 5]),
#  ('reverse', [3, 2, 5, 1]),
#  ('geometrical', [2, 3, 5, 1]),
#  ('optimum', [3, 2, 5, 1]),
#  ('extant', [1, 4, 5, 3]),
#  ('multimodal', [2, 3, 5, 1]),
#  ('distinguishable', [2, 3, 5, 1]),
#  ('reconstructed', [3, 2, 5, 1]),
#  ('supplementary', [3, 2, 5, 1]),
#  ('fold', [4, 1, 5, 3]),
#  ('undesired', [2, 3, 5, 1]),
#  ('square', [1, 4, 5, 3]),
#  ('nearby', [5, 0, 5, 5]),
#  ('curious', [3, 2, 5, 1]),
#  ('multidimensional', [4, 1, 5, 3]),
#  ('undirected', [1, 4, 5, 3]),
#  ('performant', [2, 3, 5, 1]),
#  ('ood', [0, 5, 5, 5]),
#  ('convenient', [2, 3, 5, 1]),
#  ('microscopy', [2, 3, 5, 1]),
#  ('minor', [3, 2, 5, 1]),
#  ('saddle', [3, 2, 5, 1]),
#  ('annotated', [1, 4, 5, 3]),
#  ('reversible', [3, 2, 5, 1]),
#  ('untrusted', [5, 0, 5, 5]),
#  ('synergistic', [3, 2, 5, 1]),
#  ('unrolled', [3, 2, 5, 1]),
#  ('concurrent', [2, 3, 5, 1]),
#  ('fluid', [2, 3, 5, 1]),
#  ('unchanged', [0, 5, 5, 5]),
#  ('unidirectional', [3, 2, 5, 1]),
#  ('image', [1, 4, 5, 3]),
#  ('adjustable', [3, 1, 4, 2]),
#  ('fresh', [0, 4, 4, 4]),
#  ('dangerous', [0, 4, 4, 4]),
#  ('unpaired', [1, 3, 4, 2]),
#  ('cartesian', [2, 2, 4, 0]),
#  ('outer', [4, 0, 4, 4]),
#  ('individualized', [1, 3, 4, 2]),
#  ('retinal', [3, 1, 4, 2]),
#  ('malware', [1, 3, 4, 2]),
#  ('financial', [1, 3, 4, 2]),
#  ('determinantal', [4, 0, 4, 4]),
#  ('everyday', [4, 0, 4, 4]),
#  ('cumbersome', [1, 3, 4, 2]),
#  ('compatible', [1, 3, 4, 2]),
#  ('oblivious', [4, 0, 4, 4]),
#  ('correlated', [1, 3, 4, 2]),
#  ('inevitable', [2, 2, 4, 0]),
#  ('fragile', [3, 1, 4, 2]),
#  ('phrasal', [0, 4, 4, 4]),
#  ('cyclical', [4, 0, 4, 4]),
#  ('covariate', [2, 2, 4, 0]),
#  ('controlled', [2, 2, 4, 0]),
#  ('unordered', [2, 2, 4, 0]),
#  ('instantaneous', [2, 2, 4, 0]),
#  ('measurable', [2, 2, 4, 0]),
#  ('rough', [0, 4, 4, 4]),
#  ('disparate', [3, 1, 4, 2]),
#  ('incompatible', [3, 1, 4, 2]),
#  ('multilayer', [2, 2, 4, 0]),
#  ('cnns', [2, 2, 4, 0]),
#  ('alternate', [0, 4, 4, 4]),
#  ('uncorrelated', [0, 4, 4, 4]),
#  ('ballistic', [0, 4, 4, 4]),
#  ('clipping', [4, 0, 4, 4]),
#  ('enormous', [2, 2, 4, 0]),
#  ('oracle', [4, 0, 4, 4]),
#  ('attentional', [2, 2, 4, 0]),
#  ('extrinsic', [3, 1, 4, 2]),
#  ('bias', [3, 1, 4, 2]),
#  ('abrupt', [1, 3, 4, 2]),
#  ('seminal', [2, 2, 4, 0]),
#  ('stringent', [2, 2, 4, 0]),
#  ('pyramid', [0, 4, 4, 4]),
#  ('predominant', [2, 2, 4, 0]),
#  ('checkerboard', [0, 4, 4, 4]),
#  ('loose', [2, 2, 4, 0]),
#  ('unreliable', [4, 0, 4, 4]),
#  ('slight', [2, 2, 4, 0]),
#  ('linearity', [2, 2, 4, 0]),
#  ('neuromorphic', [4, 0, 4, 4]),
#  ('dramatic', [2, 2, 4, 0]),
#  ('isometric', [2, 2, 4, 0]),
#  ('modality', [2, 2, 4, 0]),
#  ('remote', [1, 3, 4, 2]),
#  ('directed', [2, 2, 4, 0]),
#  ('refined', [1, 3, 4, 2]),
#  ('immediate', [3, 1, 4, 2]),
#  ('mechanical', [4, 0, 4, 4]),
#  ('localist', [0, 4, 4, 4]),
#  ('aggressive', [3, 1, 4, 2]),
#  ('averaged', [4, 0, 4, 4]),
#  ('sublinear', [3, 1, 4, 2]),
#  ('inferior', [3, 1, 4, 2]),
#  ('repulsive', [3, 1, 4, 2]),
#  ('proprioceptive', [3, 1, 4, 2]),
#  ('fuzzy', [3, 1, 4, 2]),
#  ('goal', [4, 0, 4, 4]),
#  ('analogical', [4, 0, 4, 4]),
#  ('quasi', [1, 3, 4, 2]),
#  ('unimodal', [1, 3, 4, 2]),
#  ('extensible', [3, 1, 4, 2]),
#  ('rational', [2, 2, 4, 0]),
#  ('omnidirectional', [1, 3, 4, 2]),
#  ('magnetic', [2, 2, 4, 0]),
#  ('corrupted', [1, 3, 4, 2]),
#  ('unperturbed', [3, 1, 4, 2]),
#  ('phylogenetic', [4, 0, 4, 4]),
#  ('required', [3, 1, 4, 2]),
#  ('stage', [1, 3, 4, 2]),
#  ('cortical', [4, 0, 4, 4]),
#  ('undefended', [2, 2, 4, 0]),
#  ('degenerate', [2, 2, 4, 0]),
#  ('deformable', [3, 1, 4, 2]),
#  ('evident', [4, 0, 4, 4]),
#  ('isotropic', [0, 4, 4, 4]),
#  ('commercial', [1, 3, 4, 2]),
#  ('polyphonic', [1, 3, 4, 2]),
#  ('aggregated', [2, 2, 4, 0]),
#  ('parameterized', [4, 0, 4, 4]),
#  ('hessian', [1, 3, 4, 2]),
#  ('encouraging', [0, 4, 4, 4]),
#  ('textural', [0, 4, 4, 4]),
#  ('elastic', [3, 1, 4, 2]),
#  ('preferred', [2, 2, 4, 0]),
#  ('layered', [2, 2, 4, 0]),
#  ('aggregate', [3, 1, 4, 2]),
#  ('advantageous', [2, 2, 4, 0]),
#  ('liquid', [2, 2, 4, 0]),
#  ('untrained', [3, 1, 4, 2]),
#  ('privileged', [4, 0, 4, 4]),
#  ('horizontal', [4, 0, 4, 4]),
#  ('adjacent', [1, 3, 4, 2]),
#  ('multinomial', [1, 3, 4, 2]),
#  ('tedious', [2, 2, 4, 0]),
#  ('explored', [1, 3, 4, 2]),
#  ('fricative', [0, 4, 4, 4]),
#  ('unsolved', [2, 2, 4, 0]),
#  ('cellular', [2, 2, 4, 0]),
#  ('decoding', [4, 0, 4, 4]),
#  ...]

# %%
to_plot_adj = sorted_adj_dist[0:50]
print(to_plot_adj)
# Out:
# [('efficient', [193, 139, 332, 54]), ('complex', [166, 114, 280, 52]), ('neural', [810, 760, 1570, 50]), ('low', [191, 241, 432, 50]), ('empirical', [133, 85, 218, 48]), ('new', [467, 420, 887, 47]), ('generative', [153, 197, 350, 44]), ('robust', [155, 112, 267, 43]), ('linear', [162, 120, 282, 42]), ('other', [181, 222, 403, 41]), ('such', [529, 488, 1017, 41]), ('original', [62, 102, 164, 40]), ('different', [304, 342, 646, 38]), ('non', [222, 185, 407, 37]), ('differentiable', [78, 41, 119, 37]), ('high', [348, 385, 733, 37]), ('similar', [75, 110, 185, 35]), ('structural', [47, 13, 60, 34]), ('particular', [146, 112, 258, 34]), ('dimensional', [96, 130, 226, 34]), ('previous', [154, 121, 275, 33]), ('diverse', [62, 30, 92, 32]), ('easy', [37, 68, 105, 31]), ('agent', [46, 16, 62, 30]), ('multiple', [159, 129, 288, 30]), ('fast', [82, 53, 135, 29]), ('compositional', [37, 9, 46, 28]), ('additional', [54, 80, 134, 26]), ('first', [151, 125, 276, 26]), ('free', [53, 79, 132, 26]), ('variable', [44, 18, 62, 26]), ('continuous', [118, 92, 210, 26]), ('physical', [52, 27, 79, 25]), ('hard', [52, 77, 129, 25]), ('single', [124, 147, 271, 23]), ('well', [145, 168, 313, 23]), ('stationary', [36, 13, 49, 23]), ('general', [127, 107, 234, 20]), ('standard', [179, 159, 338, 20]), ('negative', [27, 47, 74, 20]), ('random', [97, 78, 175, 19]), ('geometric', [41, 22, 63, 19]), ('supervised', [72, 91, 163, 19]), ('metric', [30, 48, 78, 18]), ('3d', [54, 36, 90, 18]), ('agnostic', [19, 37, 56, 18]), ('meaningful', [22, 40, 62, 18]), ('inductive', [46, 28, 74, 18]), ('effective', [129, 147, 276, 18]), ('convolutional', [132, 149, 281, 17])]

# %%
import matplotlib.pyplot as plt

# %%
x_axis = [ele[0] for ele in to_plot_adj]
accepted_freq = [ele[1][0] for ele in to_plot_adj]
rejected_freq = [ele[1][1] for ele in to_plot_adj]

# %%
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


fig, ax = plt.subplots()

x = np.arange(len(x_axis))  # the label locations
width = 0.35  # the width of the bars

rects1 = ax.bar(x - width/2, accepted_freq, width, label='Accepted papers')
rects2 = ax.bar(x + width/2, rejected_freq, width, label='Rejected papers')

ax.set_ylabel('frequency')
ax.set_xticks(x)
ax.set_xticklabels(x_axis)
ax.legend()
fig.autofmt_xdate()

# autolabel(rects1)
# autolabel(rects2)

plt.savefig("adj.png")
plt.show()

# %%
[('efficient', [193, 139, 332, 54]), ('complex', [166, 114, 280, 52]), ('neural', [810, 760, 1570, 50]), ('low', [191, 241, 432, 50]), ('empirical', [133, 85, 218, 48]), ('new', [467, 420, 887, 47]), ('generative', [153, 197, 350, 44]), ('robust', [155, 112, 267, 43]), ('linear', [162, 120, 282, 42]), ('other', [181, 222, 403, 41]), ('such', [529, 488, 1017, 41]), ('original', [62, 102, 164, 40]), ('different', [304, 342, 646, 38]), ('non', [222, 185, 407, 37]), ('differentiable', [78, 41, 119, 37]), ('high', [348, 385, 733, 37]), ('similar', [75, 110, 185, 35]), ('structural', [47, 13, 60, 34]), ('particular', [146, 112, 258, 34]), ('dimensional', [96, 130, 226, 34]), ('previous', [154, 121, 275, 33]), ('diverse', [62, 30, 92, 32]), ('easy', [37, 68, 105, 31]), ('agent', [46, 16, 62, 30]), ('multiple', [159, 129, 288, 30]), ('fast', [82, 53, 135, 29]), ('compositional', [37, 9, 46, 28]), ('additional', [54, 80, 134, 26]), ('first', [151, 125, 276, 26]), ('free', [53, 79, 132, 26]), ('variable', [44, 18, 62, 26]), ('continuous', [118, 92, 210, 26]), ('physical', [52, 27, 79, 25]), ('hard', [52, 77, 129, 25]), ('single', [124, 147, 271, 23]), ('well', [145, 168, 313, 23]), ('stationary', [36, 13, 49, 23]), ('general', [127, 107, 234, 20]), ('standard', [179, 159, 338, 20]), ('negative', [27, 47, 74, 20]), ('random', [97, 78, 175, 19]), ('geometric', [41, 22, 63, 19]), ('supervised', [72, 91, 163, 19]), ('metric', [30, 48, 78, 18]), ('3d', [54, 36, 90, 18]), ('agnostic', [19, 37, 56, 18]), ('meaningful', [22, 40, 62, 18]), ('inductive', [46, 28, 74, 18]), ('effective', [129, 147, 276, 18]), ('convolutional', [132, 149, 281, 17])]
# Out:
# ['efficient',
#  'complex',
#  'neural',
#  'low',
#  'empirical',
#  'new',
#  'generative',
#  'robust',
#  'linear',
#  'other',
#  'such',
#  'original',
#  'different',
#  'non',
#  'differentiable',
#  'high',
#  'similar',
#  'structural',
#  'particular',
#  'dimensional',
#  'previous',
#  'diverse',
#  'easy',
#  'agent',
#  'multiple',
#  'fast',
#  'compositional',
#  'additional',
#  'first',
#  'free',
#  'variable',
#  'continuous',
#  'physical',
#  'hard',
#  'single',
#  'well',
#  'stationary',
#  'general',
#  'standard',
#  'negative',
#  'random',
#  'geometric',
#  'supervised',
#  'metric',
#  '3d',
#  'agnostic',
#  'meaningful',
#  'inductive',
#  'effective',
#  'convolutional']

# %%
top50adj = sorted_adj_dist[0:55]
topadj = [ele[0] for ele in top50adj]
print(topadj)
# Out:
# ['efficient', 'complex', 'neural', 'low', 'empirical', 'new', 'generative', 'robust', 'linear', 'other', 'such', 'original', 'different', 'non', 'differentiable', 'high', 'similar', 'structural', 'particular', 'dimensional', 'previous', 'diverse', 'easy', 'agent', 'multiple', 'fast', 'compositional', 'additional', 'first', 'free', 'variable', 'continuous', 'physical', 'hard', 'single', 'well', 'stationary', 'general', 'standard', 'negative', 'random', 'geometric', 'supervised', 'metric', '3d', 'agnostic', 'meaningful', 'inductive', 'effective', 'convolutional', 'molecular', 'objective', 'noisy', 'sensitive', 'auxiliary']

# %%
rev_adj_data = read_pickle_file("ICLR data/review_2019_adj.pickle")

# %%
rev_adj_data
# Out:
# {'seq2seq+attn': [0, 1],
#  'gyrocentroid': [0, 1],
#  'random': [906, 1182],
#  'quotient': [2, 1],
#  'noisy': [309, 323],
#  'computed': [1, 6],
#  'phantom': [2, 0],
#  'gradient': [2, 0],
#  'tenuous': [2, 11],
#  'steerable': [7, 6],
#  'discuss': [2, 1],
#  'supervized': [1, 0],
#  'ambitious': [7, 10],
#  'hamming': [1, 0],
#  'prone': [18, 42],
#  'c++': [0, 2],
#  'deceptive': [8, 8],
#  'eigen': [5, 6],
#  'compatible': [27, 20],
#  'adjustable': [4, 0],
#  'hotpotqa': [1, 0],
#  'hasty': [1, 4],
#  'sorry': [1, 7],
#  'intermediary': [9, 1],
#  'goodfellow': [2, 4],
#  'annealing': [1, 1],
#  'nominative': [1, 0],
#  '\\mathcal{l}^1_{l1}$': [0, 1],
#  'unrestricted': [37, 21],
#  'interatomic': [2, 0],
#  'hierarchival': [0, 1],
#  'normalizing': [49, 61],
#  'prefixed': [2, 0],
#  'central': [85, 127],
#  'concise': [31, 40],
#  '700k': [0, 3],
#  'analytical': [36, 38],
#  'gendered': [3, 1],
#  'constrained': [19, 25],
#  'validation': [5, 11],
#  'ironic': [1, 0],
#  'cartesian': [6, 14],
#  'predicate': [18, 2],
#  'parallelwavenet': [0, 1],
#  'introduce': [2, 0],
#  'consolidated': [0, 1],
#  'lingual': [67, 57],
#  'burdensome': [4, 0],
#  'pinyin': [0, 2],
#  'coarsened': [1, 2],
#  'entailed': [1, 0],
#  'fig.6': [0, 1],
#  'humanoid': [12, 15],
#  'prehensile': [0, 1],
#  'underdetermined': [3, 0],
#  'boxcar': [1, 0],
#  'original': [813, 1287],
#  'algorithm': [28, 39],
#  'extendable': [5, 6],
#  'extrapolated': [0, 2],
#  'enumerative': [2, 0],
#  'u^4': [1, 0],
#  'erm': [5, 0],
#  'needless': [2, 1],
#  'modulatable': [1, 0],
#  'behaved': [3, 0],
#  'affect': [2, 0],
#  '||w_t': [1, 0],
#  'admm': [0, 2],
#  'edge': [1, 0],
#  'overselling': [0, 1],
#  'referenced': [14, 11],
#  'f(x': [2, 0],
#  'magical': [4, 3],
#  'old': [102, 163],
#  'damped': [0, 2],
#  'epsilon': [1, 0],
#  'abstracted': [1, 0],
#  'direclty': [1, 1],
#  'testable': [1, 2],
#  'dead': [4, 19],
#  'straightforward': [250, 452],
#  'reminescent': [1, 0],
#  'adaptiveness': [0, 2],
#  'mega': [0, 1],
#  'unclosed': [0, 1],
#  '-genesis': [1, 0],
#  'eligible': [4, 0],
#  'desired': [0, 3],
#  'rafique': [1, 0],
#  'monolingual': [14, 23],
#  'financial': [0, 16],
#  'sophisticated': [49, 50],
#  'feedfoward': [0, 1],
#  'cnn': [0, 1],
#  'disconcerting': [0, 2],
#  'intermediate': [126, 173],
#  'programatic': [0, 1],
#  'learnt': [28, 7],
#  'mpo': [1, 0],
#  'special': [138, 211],
#  'egregious': [5, 6],
#  'obtained': [23, 35],
#  'public': [45, 80],
#  'retinopathy': [0, 2],
#  'fasttext': [4, 1],
#  'langauge': [4, 0],
#  "s'_{x}$": [0, 2],
#  'annoyed': [2, 0],
#  'recommended': [1, 2],
#  'rekindled': [0, 2],
#  '500k': [4, 0],
#  'internal': [72, 106],
#  'acute': [2, 2],
#  'stationary': [121, 125],
#  'visited': [0, 8],
#  'l2-based': [1, 0],
#  'dgmn': [0, 1],
#  'softadam': [0, 2],
#  'connectionist': [1, 2],
#  'o+(og': [0, 3],
#  'strided': [2, 0],
#  'counterexample-': [2, 0],
#  'northern': [0, 1],
#  'l_infty': [3, 2],
#  'teaching+': [2, 0],
#  'conjectural': [0, 1],
#  'ischemic': [2, 0],
#  'indifferent': [0, 2],
#  'gated': [0, 2],
#  'followup': [1, 2],
#  'sharable': [0, 1],
#  'puzzling': [2, 0],
#  'variability-': [0, 2],
#  'measured': [2, 0],
#  'trigonometric': [1, 1],
#  'curvature': [1, 0],
#  'conv2d': [0, 2],
#  'distributioned': [0, 2],
#  "e'$": [1, 0],
#  'fragile': [2, 9],
#  '~md': [1, 0],
#  'dat': [2, 0],
#  'usuable': [1, 0],
#  'debiased': [3, 0],
#  'cifar10/cifar100': [0, 2],
#  'fundametal': [0, 1],
#  'autocurricula': [1, 0],
#  'path-': [1, 0],
#  'la': [0, 2],
#  'prlbo': [0, 2],
#  'y_i1': [0, 2],
#  'autoender': [0, 2],
#  'productive': [1, 1],
#  'testing/': [0, 1],
#  'mythological': [0, 1],
#  'verified': [3, 5],
#  'univariable': [1, 0],
#  'hindsight': [2, 0],
#  '32-dimensional': [0, 2],
#  'motivated': [399, 353],
#  'strawman': [0, 2],
#  'implementable': [1, 2],
#  'entangled': [5, 1],
#  'axis': [4, 8],
#  'sgd': [0, 2],
#  'uninspired': [0, 1],
#  'decent': [43, 42],
#  'amazing': [8, 6],
#  'sparisified': [0, 2],
#  'imperfect': [27, 37],
#  'saturating': [0, 16],
#  'unconstraint': [0, 2],
#  '13th': [3, 3],
#  'hypercomplex': [4, 0],
#  'overclaimed': [0, 2],
#  'post': [103, 136],
#  'adverse': [4, 9],
#  'interactional': [0, 2],
#  'jumpy': [0, 3],
#  'purported': [3, 5],
#  'integrated': [2, 2],
#  'undiscounted': [2, 3],
#  '\\tilde{\\theta_2': [0, 1],
#  '20th': [2, 1],
#  'obvious': [218, 330],
#  'specified': [21, 18],
#  'disadvantaged': [1, 0],
#  'vqa(visual': [1, 0],
#  'limbed': [1, 0],
#  'neccessary': [0, 2],
#  'lp': [1, 2],
#  'energy': [2, 0],
#  'tractable': [78, 64],
#  'http://animalaiolympics.com/': [4, 0],
#  'essay': [0, 1],
#  'orthonormal': [7, 11],
#  'r’th': [0, 1],
#  'traing': [1, 0],
#  'benefitial': [4, 0],
#  'level': [10, 19],
#  'supplement': [2, 0],
#  'swap': [0, 2],
#  'nodal': [0, 6],
#  'welcome': [36, 42],
#  'tsallis': [0, 2],
#  'modified': [5, 3],
#  'unsatisfying': [1, 6],
#  'safe': [39, 68],
#  'tampered': [0, 1],
#  'p(o': [0, 2],
#  'associated': [2, 5],
#  'increment': [1, 0],
#  'negativity': [2, 0],
#  'verbal': [2, 13],
#  'glad': [24, 21],
#  'language': [0, 9],
#  'polish': [0, 1],
#  'actual': [288, 375],
#  'gnns': [2, 0],
#  'repository': [1, 0],
#  'activated': [1, 0],
#  'loopless': [4, 0],
#  'empirical': [1260, 1592],
#  'f$': [0, 2],
#  'instantiate': [0, 2],
#  'foolable': [0, 1],
#  'measurable': [4, 8],
#  'calligraphic': [0, 2],
#  'hurried': [0, 2],
#  'disheartening': [1, 0],
#  'annealable': [1, 0],
#  'factual': [8, 12],
#  'residue': [0, 4],
#  'about': [2, 3],
#  'multiview': [5, 3],
#  'wired': [3, 1],
#  'hurtful': [0, 3],
#  'nondestructive': [0, 1],
#  'nonpolynomial': [2, 0],
#  'econometric': [0, 4],
#  'overparamatrized': [0, 2],
#  'hypernym': [0, 2],
#  'u': [17, 8],
#  'final': [504, 671],
#  'highlight': [0, 2],
#  'calibrated': [7, 8],
#  'paramet': [349, 464],
#  'grammatical': [69, 156],
#  'away': [2, 0],
#  'metropolis': [0, 2],
#  'underexplained': [0, 1],
#  'determinant': [0, 3],
#  'asynchronous': [40, 60],
#  'stabilizable': [1, 0],
#  'ecological': [0, 1],
#  'q(m|x': [2, 0],
#  'comparing': [0, 2],
#  'strainghtforward': [0, 1],
#  'offical': [1, 0],
#  'trainable': [45, 52],
#  'funny': [2, 2],
#  's\\notin': [1, 0],
#  'ma)rl': [0, 1],
#  'detailed': [537, 678],
#  'pgan': [2, 0],
#  'occluded': [6, 2],
#  'graph': [31, 31],
#  'outperforming': [3, 4],
#  'obliged': [1, 0],
#  'unrelevant': [2, 0],
#  'pointing': [0, 1],
#  'detached': [0, 2],
#  'third': [64, 142],
#  'satisfactory': [56, 59],
#  'lofty': [0, 1],
#  'softmaxed': [2, 0],
#  'induced': [11, 15],
#  'o': [2, 0],
#  'porous': [1, 4],
#  'faithfull': [0, 1],
#  'analyitc': [1, 0],
#  'unwilling': [0, 2],
#  'sematic': [1, 0],
#  'graceful': [0, 1],
#  'leatoric': [0, 1],
#  'sim2real': [5, 1],
#  'clever': [56, 19],
#  'miscalibrated': [0, 1],
#  'prsented': [1, 0],
#  'leaned': [1, 0],
#  'linearized': [8, 9],
#  'guacamol': [2, 0],
#  'sided': [2, 2],
#  'persuasive': [4, 19],
#  'grave': [0, 1],
#  'macro': [22, 71],
#  'polar': [0, 3],
#  'accompanying': [11, 4],
#  'varpsom': [0, 1],
#  'selected': [2, 3],
#  'perfect': [66, 95],
#  'https://arxiv.org/pdf/1807.09705.pdf': [0, 1],
#  'sizes': [0, 2],
#  'seval': [1, 0],
#  'unfamiliar': [29, 27],
#  'white': [54, 133],
#  'vain': [0, 1],
#  'cyclegan': [6, 5],
#  'document': [3, 1],
#  'side': [1, 1],
#  'unnoticed': [1, 0],
#  'geom': [1, 0],
#  'simplex': [0, 2],
#  'electric': [3, 0],
#  'asymptotoic': [0, 1],
#  'embed': [2, 2],
#  'jittery': [0, 1],
#  'potent': [3, 2],
#  'bottommost': [0, 1],
#  'urgent': [1, 2],
#  'unknown': [106, 163],
#  'combinatorial': [44, 43],
#  'unassigned': [0, 6],
#  'inject': [1, 3],
#  'objective': [263, 333],
#  'known': [16, 32],
#  'delusional': [6, 18],
#  'explosive': [0, 3],
#  'fluent': [4, 5],
#  'masking': [1, 2],
#  'plaintext': [1, 0],
#  'unhealthy': [0, 2],
#  'mnemonic': [0, 1],
#  'crosslingual': [6, 0],
#  'hierarchical': [233, 387],
#  'lottery': [1, 2],
#  'ha2018': [2, 0],
#  'future': [416, 329],
#  'page': [2, 0],
#  'replicate': [0, 1],
#  'manifold': [25, 72],
#  'optical': [20, 65],
#  'unnecessarily': [0, 6],
#  'x(t': [5, 0],
#  'right': [279, 437],
#  'dataflow': [7, 4],
#  'intense': [2, 4],
#  '+1.4': [0, 2],
#  'uncharacterized': [2, 0],
#  'digital': [3, 7],
#  'ambiguous': [43, 75],
#  '\\hat{f}_\\phi': [2, 0],
#  'perpetual': [0, 1],
#  'generative': [542, 774],
#  'uninvestigated': [0, 2],
#  'max': [18, 15],
#  'reversed': [2, 5],
#  '2th': [2, 0],
#  'correctioncan': [0, 1],
#  'd_{s+}.': [0, 2],
#  'far': [5, 2],
#  'uninformative': [11, 17],
#  'black': [203, 256],
#  'unlikely': [29, 63],
#  'wasteful': [9, 4],
#  'spin_object': [0, 2],
#  '25-second': [2, 0],
#  'honest': [29, 15],
#  'famous': [12, 12],
#  'varaible': [0, 1],
#  'opitmal': [0, 1],
#  'ad': [0, 1],
#  'representable': [2, 1],
#  'colloquial': [1, 4],
#  'discrete': [294, 354],
#  'penal': [4, 0],
#  'assemble': [0, 4],
#  'biased-': [0, 2],
#  'stark': [10, 5],
#  'gcmm': [0, 1],
#  'imagenet-128': [2, 0],
#  'g_{11': [0, 1],
#  'biophysical': [0, 1],
#  '~400k': [0, 2],
#  'tested': [3, 2],
#  '4th': [18, 25],
#  'disentangleв': [2, 0],
#  'behavioural': [1, 7],
#  'catastrophic': [62, 112],
#  'fixed': [7, 28],
#  'unconstrained': [19, 14],
#  'malicious': [7, 13],
#  'l_learner^cls': [2, 0],
#  'unsettled': [0, 1],
#  'capped': [2, 0],
#  'falsifiable': [5, 3],
#  'eg': [3, 0],
#  'beta': [2, 8],
#  'additional': [960, 1067],
#  'layerwise': [5, 4],
#  'square': [41, 68],
#  'political': [4, 3],
#  'incongruous': [1, 2],
#  'sweet': [5, 4],
#  'nervous': [2, 1],
#  'eloquent': [1, 0],
#  'h^{(0)}_e': [0, 1],
#  'mixup': [0, 1],
#  '\\sqrt{d': [1, 1],
#  'a)*k/(k-1)}.': [0, 1],
#  'floating': [2, 4],
#  'asmyptotic': [0, 2],
#  "constructive)—couldn't": [2, 0],
#  'horizon': [1, 0],
#  'underflow': [0, 8],
#  'kind': [4, 6],
#  'somewhat': [1, 0],
#  'parasitized': [0, 2],
#  'foreground': [2, 2],
#  'bert': [83, 84],
#  'rumor': [2, 4],
#  'corporate': [2, 0],
#  'eq.(3': [0, 1],
#  'narrow': [50, 82],
#  'resilient': [5, 7],
#  'signficant': [1, 4],
#  'kantorovich': [2, 0],
#  'icip19': [0, 2],
#  '\\frac{1}{exp(bn(linear': [0, 1],
#  'toy': [6, 6],
#  'varible': [1, 0],
#  'niceness': [0, 2],
#  'rotational': [20, 11],
#  'undergraduate': [0, 1],
#  '26th': [1, 1],
#  'pathological': [6, 11],
#  'frequent': [19, 21],
#  'f1': [2, 5],
#  'nonextensive': [0, 1],
#  'training': [62, 81],
#  'd_t': [0, 3],
#  'unorthodox': [1, 2],
#  'skeptic': [0, 2],
#  'aboupt': [0, 1],
#  'expressible': [10, 7],
#  'underparaterized': [0, 2],
#  'warm': [25, 39],
#  'wd+dropout': [0, 1],
#  'thi': [0, 2],
#  'popular': [162, 216],
#  'solitary': [1, 0],
#  'laudable': [4, 5],
#  'brief': [50, 81],
#  'oversized': [0, 1],
#  'bnn': [1, 0],
#  'boxed': [0, 1],
#  'untrusted': [1, 4],
#  'interventional': [2, 22],
#  'insideness': [4, 4],
#  'huge': [101, 148],
#  '1-lipschitz': [1, 3],
#  'id': [3, 3],
#  'simultaneous': [41, 11],
#  'redundant': [62, 95],
#  'og||2': [0, 1],
#  'distinct': [68, 86],
#  'stiff': [3, 0],
#  'fractal': [5, 0],
#  'forth': [1, 2],
#  'image': [9, 15],
#  'recall@k': [1, 0],
#  'portable': [0, 5],
#  '16-token': [2, 0],
#  'first-': [0, 2],
#  'unsatisfactory': [4, 18],
#  'amssymb': [1, 0],
#  'acylic': [0, 1],
#  'downstream': [176, 209],
#  'm|m|': [0, 2],
#  'undersparsed': [0, 1],
#  'unsustainable': [0, 2],
#  'commendable': [10, 10],
#  'delineate': [1, 0],
#  'overlooked': [0, 1],
#  'jp(pj)^t': [0, 1],
#  'multilayer': [1, 7],
#  'https://arxiv.org/pdf/1903.11680.pdf': [2, 0],
#  'uncertified': [1, 0],
#  'g(\\cdot': [2, 0],
#  'regular': [104, 123],
#  'lstm2': [0, 2],
#  'objectives(balanced': [0, 2],
#  'kenyan': [0, 1],
#  'retraining': [0, 1],
#  'cute': [5, 2],
#  'lexicographical': [0, 1],
#  'arbitary': [2, 0],
#  'nontrivial': [29, 20],
#  'encoding': [1, 1],
#  'total': [140, 217],
#  'unwritten': [0, 2],
#  'de': [5, 14],
#  'adaptable': [6, 3],
#  'unquantized': [1, 0],
#  '\\ell_\\inf': [1, 0],
#  'peer': [0, 1],
#  'interactive': [23, 41],
#  'contradictory': [20, 41],
#  'searched': [14, 4],
#  'backdoored': [2, 2],
#  'human': [396, 583],
#  'dependant': [5, 2],
#  'friedland': [2, 0],
#  'embossing': [0, 2],
#  'person': [0, 4],
#  'heavy': [80, 71],
#  'modulo': [11, 10],
#  'ambivalent': [4, 6],
#  'recurrant': [2, 0],
#  '-quantitative': [0, 1],
#  'incorporated': [3, 0],
#  'blinded': [0, 1],
#  'revised': [11, 7],
#  'pseudometric': [2, 0],
#  'impenetrable': [3, 2],
#  'uncorrelated': [3, 10],
#  'essential': [68, 125],
#  'eventual': [1, 6],
#  'anytime': [0, 1],
#  'vacuous': [10, 20],
#  'latex.': [1, 2],
#  'cosmological': [1, 0],
#  'immutable': [3, 1],
#  'reconstructive': [2, 1],
#  'broad': [119, 167],
#  'minibatched': [2, 0],
#  'slight': [45, 72],
#  'guided': [0, 2],
#  'n_{m+1': [0, 1],
#  'unblurred': [1, 0],
#  '|e|$': [2, 0],
#  'reliable': [50, 72],
#  'easy': [1099, 1184],
#  'misc': [2, 3],
#  'overhead': [4, 5],
#  'flops': [5, 6],
#  'neater': [0, 1],
#  'pearl': [0, 1],
#  'methological': [0, 2],
#  'snapshot': [3, 5],
#  'post)-processing': [1, 0],
#  'generate': [1, 0],
#  '19.84ms': [1, 0],
#  '40th': [1, 1],
#  'create': [2, 0],
#  'termporal': [2, 0],
#  'lateral': [4, 3],
#  'peaked': [6, 2],
#  'upscaling': [0, 2],
#  'abusive': [1, 2],
#  'pertinent': [13, 10],
#  'ordered': [0, 2],
#  'peakiness': [8, 0],
#  'illustrative': [48, 32],
#  'twice': [0, 1],
#  'defensible': [0, 1],
#  'foveal': [0, 2],
#  'obfuscating': [2, 0],
#  'weak': [870, 1039],
#  'allow': [1, 0],
#  'utzappos50': [0, 1],
#  'ary': [1, 5],
#  'effective': [576, 471],
#  'role': [2, 0],
#  'summ': [0, 2],
#  'turkish': [5, 1],
#  'h_j': [1, 0],
#  'body': [1, 0],
#  'bitwidth': [2, 6],
#  'gini': [0, 1],
#  'ok': [62, 67],
#  'possible': [979, 1047],
#  'g/||w_1': [0, 2],
#  'tiny': [25, 42],
#  'matching': [1, 3],
#  '\\phi_{t=0': [1, 0],
#  'unncessary': [2, 0],
#  'contrived': [4, 16],
#  'dumb': [1, 1],
#  'outperform': [16, 12],
#  'degrade': [1, 0],
#  'synaptic': [9, 16],
#  'g_t^{(t)}$': [0, 1],
#  'citep': [2, 1],
#  'sparsemax': [0, 2],
#  'gru': [2, 0],
#  'agnostic': [93, 120],
#  'colorblind': [3, 0],
#  'connectedness': [2, 0],
#  'forward': [128, 158],
#  'runnable': [0, 1],
#  'c^{t-1}]$': [1, 0],
#  'antipodal': [3, 0],
#  'hindre': [2, 0],
#  'delayed': [1, 5],
#  'uneasy': [0, 1],
#  'detract': [2, 0],
#  'maurey': [1, 0],
#  'x_i': [1, 0],
#  'disciminative': [0, 1],
#  'warmup': [6, 3],
#  'projectile': [0, 5],
#  'spec': [4, 0],
#  'quantitatively': [0, 1],
#  'hierarhical': [1, 0],
#  'adam': [0, 3],
#  'pnml': [0, 1],
#  '10-fold': [5, 2],
#  'magic': [0, 7],
#  'invariant': [144, 230],
#  'quantiative': [1, 1],
#  'j_lpp': [0, 1],
#  'interdependent': [1, 0],
#  'albedo': [0, 1],
#  'double': [78, 96],
#  'n_{s}(v': [1, 0],
#  'aleaotric': [0, 1],
#  'theoretical': [1355, 1542],
#  'sane': [1, 0],
#  'translational': [10, 10],
#  'linearly': [6, 13],
#  'smooth': [147, 145],
#  'diagrammatic': [4, 2],
#  'outdated': [2, 12],
#  'unstable/': [2, 0],
#  '|dh': [0, 2],
#  'process': [1, 0],
#  'icml18': [0, 2],
#  'usefull': [0, 1],
#  'upper': [205, 251],
#  'virtuous': [4, 0],
#  'p_gtdistribution(x': [0, 1],
#  'ment': [0, 1],
#  '-below': [2, 0],
#  'intuitive': [314, 365],
#  'antibacterial': [0, 1],
#  'trail': [2, 0],
#  'nonboosted': [0, 2],
#  'nonlinearity': [0, 2],
#  'p(y_tilde': [0, 2],
#  'approximate': [157, 168],
#  'a.k.a': [7, 7],
#  'plural': [12, 8],
#  'disqualifying': [0, 1],
#  'tertiary': [0, 1],
#  'frequentist': [5, 5],
#  'fully-': [0, 1],
#  'upsampling': [3, 0],
#  'mathematic': [1, 1],
#  'aggressive': [18, 20],
#  'unfavorable': [2, 2],
#  'd$-dimensional': [2, 5],
#  'unbelievable': [2, 0],
#  'mitigated': [1, 0],
#  'annoying': [5, 4],
#  'exciting': [63, 43],
#  'f1-based': [0, 2],
#  'mathemeatical': [2, 0],
#  'asymetric': [6, 0],
#  'bipedal': [2, 0],
#  'moderate': [23, 42],
#  'o(s*s*c*l': [0, 1],
#  'implied': [0, 14],
#  'particular': [1084, 1281],
#  'haze': [0, 1],
#  'hxwxc': [0, 1],
#  'traning': [1, 0],
#  'former': [75, 96],
#  'aware': [199, 198],
#  'comforting': [2, 0],
#  'aversarial': [0, 1],
#  'asymptotic': [87, 83],
#  'train': [6, 5],
#  'layered': [3, 5],
#  'ingenious': [2, 0],
#  'heavyside': [0, 1],
#  'multilevel': [1, 0],
#  'stabilizing': [1, 0],
#  'illustrating': [0, 1],
#  'feminine': [1, 0],
#  'x10': [2, 0],
#  'inferior': [21, 33],
#  'infogan': [1, 8],
#  'constant': [277, 312],
#  'modern': [60, 109],
#  'else': [2, 1],
#  'invertibility': [0, 2],
#  'lorentzian': [0, 1],
#  'tweaked': [0, 2],
#  'lagrangean': [1, 0],
#  'inaccessible': [5, 4],
#  '34th': [10, 17],
#  'f_linear': [0, 1],
#  'maximal': [19, 24],
#  'formatted': [2, 0],
#  'hoc': [2, 1],
#  'lasso': [0, 1],
#  'maxial': [0, 2],
#  'individualized': [1, 3],
#  'inherent': [32, 31],
#  'constructive': [15, 5],
#  'predictable': [7, 24],
#  'fast': [316, 316],
#  'rewarding': [6, 4],
#  'ongoing': [3, 7],
#  'undecided': [1, 2],
#  'concatenating': [0, 2],
#  'national': [0, 2],
#  'disjunctive': [2, 1],
#  'transparent': [16, 7],
#  'prospective': [0, 2],
#  'dirty': [2, 2],
#  'wwwdiscuss': [2, 0],
#  'enjoyable': [12, 3],
#  'unsuitable': [4, 8],
#  'futher': [0, 1],
#  'solar': [5, 2],
#  'million+': [1, 0],
#  'accelerate': [2, 3],
#  'contraint': [1, 0],
#  'overview': [4, 4],
#  'constrastive': [0, 1],
#  'appreciable': [1, 1],
#  'intractable': [40, 35],
#  'cp': [0, 1],
#  '36-dimensional': [1, 0],
#  'conditional': [384, 490],
#  'subtle': [23, 19],
#  'reproducable': [2, 0],
#  'mixture': [33, 62],
#  'material': [2, 1],
#  'a_jn': [0, 1],
#  'loaded': [2, 1],
#  'trimodal': [0, 2],
#  '\\delta_2': [1, 0],
#  'underparameterized': [2, 10],
#  'italic': [7, 0],
#  'heartbeat': [0, 1],
#  'particulat': [2, 1],
#  'lossed': [0, 1],
#  'entropic': [6, 2],
#  'pale': [2, 0],
#  'plannable': [0, 3],
#  'polynomial': [65, 65],
#  'oxford': [1, 0],
#  'conservative': [21, 28],
#  'l_q': [2, 0],
#  'segmented': [7, 14],
#  'outperforms': [0, 1],
#  'resealable': [0, 2],
#  'memory': [2, 0],
#  'implmented': [0, 1],
#  'revolutionary': [0, 1],
#  'light': [33, 36],
#  'retrieval': [1, 8],
#  'worked': [0, 1],
#  'inoffensiveness': [2, 0],
#  'boolean': [49, 93],
#  'rumour': [0, 18],
#  'aractingi': [0, 1],
#  'quantifiable': [4, 3],
#  'l1': [0, 1],
#  'uncanny': [0, 2],
#  'preferential': [3, 1],
#  'bnns': [2, 0],
#  'cross': [260, 338],
#  'converted': [1, 0],
#  'affine': [41, 50],
#  'wierd': [2, 0],
#  'un"important': [0, 1],
#  'rational': [5, 25],
#  'valuable': [264, 158],
#  'intrigued': [0, 2],
#  'below': [3, 14],
#  'locomotive': [0, 1],
#  'boundedness': [0, 6],
#  'cils': [1, 0],
#  'marl': [0, 1],
#  'l’’’(0))^2': [0, 2],
#  'irregular': [2, 22],
#  'g$.': [0, 1],
#  'unpromising': [2, 5],
#  'pervious': [0, 3],
#  'quadractic': [2, 0],
#  'guaranteed': [1, 1],
#  'pugan': [0, 2],
#  'unpredictive': [1, 0],
#  'rewind': [1, 0],
#  'extrapolate"-style': [0, 2],
#  'p_true': [0, 6],
#  'resnet-18': [2, 1],
#  'unfold': [0, 1],
#  'expoential': [0, 1],
#  'parallelizable': [0, 2],
#  'pronged': [0, 3],
#  'swapping': [0, 1],
#  'represent': [3, 2],
#  'uploaded': [1, 1],
#  'arxiv': [4, 0],
#  'module': [16, 3],
#  'erasing': [0, 1],
#  'modality': [2, 0],
#  'texturized': [0, 2],
#  'anonymous': [5, 18],
#  'presented': [16, 23],
#  'ethnic': [1, 0],
#  'l1/l2': [0, 3],
#  'ornamental': [1, 1],
#  'disposable': [0, 1],
#  'differentiated': [1, 0],
#  'regularized': [14, 13],
#  'dag': [2, 0],
#  'medical': [48, 59],
#  'iresnet': [0, 2],
#  'primary': [124, 165],
#  '13-layer': [0, 2],
#  'read': [2, 0],
#  'slow': [127, 121],
#  'holy': [2, 2],
#  'unsure': [34, 38],
#  'strange': [67, 144],
#  'intuitional->intuitive': [2, 0],
#  'g$': [0, 2],
#  'bigan': [2, 2],
#  'omnidirectional': [4, 0],
#  '\\log': [1, 12],
#  'pad': [0, 1],
#  'fprint': [1, 0],
#  'flow': [0, 2],
#  'reachable': [5, 0],
#  'mr': [0, 1],
#  'critic': [13, 20],
#  'srn-50': [1, 0],
#  'ws': [1, 0],
#  'progressive': [38, 67],
#  'ncs-50x1': [0, 1],
#  'stored': [1, 2],
#  '8].': [0, 1],
#  'openreview': [3, 0],
#  'iteratively': [0, 2],
#  'alternative': [127, 170],
#  'classical': [146, 129],
#  'unaddressed': [3, 9],
#  'supervision': [0, 1],
#  'interpolatory': [0, 1],
#  'plenty': [1, 8],
#  'unfolded': [0, 3],
#  'prepared': [0, 4],
#  'differentiable': [260, 257],
#  'automatical': [2, 1],
#  'lousy': [1, 0],
#  'terminal': [14, 37],
#  '\\alpha_0/k$': [0, 1],
#  'propotional': [0, 2],
#  'wise': [235, 300],
#  'https://arxiv.org/abs/1903.11960': [2, 0],
#  'binarized': [1, 0],
#  'outlying': [1, 1],
#  'ensenble': [1, 0],
#  'step': [46, 37],
#  'upsampled': [2, 1],
#  'q*.': [2, 0],
#  'imbalanced': [8, 30],
#  'generalized': [40, 64],
#  'unchanged': [39, 55],
#  'brutal': [1, 1],
#  'part': [2, 2],
#  'vectorial': [0, 4],
#  'underlined': [1, 0],
#  'aerial': [0, 5],
#  'mapped': [2, 6],
#  'expansive': [3, 1],
#  'english': [50, 63],
#  'noised': [2, 4],
#  '10-step': [0, 3],
#  'perturbation': [2, 0],
#  'interpratable': [4, 0],
#  'https://openreview.net/forum?id=ryg7vA4tPB': [1, 2],
#  'incompressible': [2, 2],
#  'reponse': [0, 2],
#  'proximal': [37, 34],
#  'importable': [2, 0],
#  'receptive': [29, 65],
#  'ended': [13, 2],
#  'demonstrated': [1, 1],
#  'evaluated': [12, 31],
#  'soon-': [0, 1],
#  'masculine': [1, 0],
#  'collected': [10, 12],
#  'aforementioned': [30, 56],
#  'primal': [14, 32],
#  'saturate': [1, 0],
#  'overconfident': [3, 15],
#  'gentle': [4, 4],
#  'mean+-std': [0, 1],
#  'bertsum': [0, 8],
#  'k=1$.': [0, 2],
#  'fairseq': [1, 0],
#  'utmost': [2, 0],
#  '400k': [0, 3],
#  'padme': [0, 1],
#  'http://papers.nips.cc/paper/3201-a-kernel-statistical-test-of-independence.pdf': [0,
#   2],
#  'pointwise': [1, 3],
#  'iterative': [82, 148],
#  'projection': [0, 1],
#  'fractional': [22, 32],
#  'projective': [28, 4],
#  'd_0.5': [0, 2],
#  'salient': [5, 2],
#  'eastern': [2, 0],
#  'interscale': [2, 0],
#  'overlapping': [5, 8],
#  'female': [0, 2],
#  '\\sigma_j': [0, 1],
#  'draw': [5, 0],
#  'equivalent': [181, 210],
#  'keyframe': [1, 2],
#  'vietnamese': [4, 1],
#  'arity-3': [1, 0],
#  'contiguous': [6, 14],
#  'descent': [0, 2],
#  'dorefa': [0, 2],
#  'detected': [3, 0],
#  'E+l2': [0, 2],
#  'esoteric': [0, 2],
#  'upwards': [0, 1],
#  'marginal': [134, 280],
#  'fictitious': [6, 15],
#  'neccesary': [0, 1],
#  'indefinite': [3, 0],
#  'localizable': [1, 2],
#  'unreal': [0, 2],
#  'a_{ij': [0, 2],
#  'bibliographic': [2, 9],
#  'reference': [2, 0],
#  'a_k': [0, 2],
#  'such': [2385, 3387],
#  'down': [7, 11],
#  'dependable': [1, 0],
#  'synctatic': [0, 2],
#  'view': [26, 55],
#  'time': [2, 2],
#  'tense': [5, 4],
#  'distillated': [0, 1],
#  'prescribed': [1, 2],
#  'express': [2, 0],
#  'substantial': [112, 131],
#  'customized': [3, 0],
#  'irrational': [0, 5],
#  'genuine': [6, 8],
#  'l1-like': [1, 0],
#  'w_i': [0, 2],
#  'workable': [0, 1],
#  'underthe': [2, 0],
#  'ebmm': [1, 0],
#  'm+q)-dimensional': [0, 2],
#  'jacobian': [46, 42],
#  'o(t\\sqrt(t': [0, 2],
#  'photometric': [5, 4],
#  'unordered': [10, 13],
#  'uncalibrated': [3, 3],
#  'plus': [6, 4],
#  'proof': [5, 4],
#  'peripheral': [2, 4],
#  '\\sigma_v': [0, 2],
#  'finetuneable': [0, 2],
#  'unsorted': [0, 2],
#  'polymorphic': [1, 0],
#  'concerning': [3, 7],
#  'leant': [0, 2],
#  'fig.1a': [0, 1],
#  'connected': [45, 77],
#  'deflected': [0, 1],
#  'disadvantageous': [0, 1],
#  'decreasing': [3, 2],
#  'multimodal': [26, 80],
#  'hamiltonian': [38, 3],
#  'powerful': [104, 106],
#  'in-': [0, 6],
#  'matric': [1, 4],
#  'isotropic': [16, 27],
#  'homophilous': [1, 0],
#  'notable': [29, 14],
#  'nrl': [0, 1],
#  'minibatch': [4, 1],
#  'succinct': [9, 6],
#  'transdimensional': [1, 1],
#  'fashionmnist': [2, 1],
#  'pretty': [8, 4],
#  ...}

# %%
for k in rev_adj_data:
    rev_adj_data[k].append(rev_adj_data[k][0]+rev_adj_data[k][1])
    rev_adj_data[k].append(abs(rev_adj_data[k][0]-rev_adj_data[k][1]))

# %%
rev_sorted_adj_freq = sorted(rev_adj_data.items(), key=lambda e: e[1][2], reverse=True)
rev_sorted_adj_dist = sorted(rev_adj_data.items(), key=lambda e: e[1][3], reverse=True)

# %%
rev_sorted_adj_dist.pop(7)
# Out:
# ('#', [1752, 982, 2734, 770])

# %%
rev_to_plot_adj = rev_sorted_adj_dist[0:15]
print(rev_to_plot_adj)
# Out:
# [('other', [3850, 5062, 8912, 1212]), ('different', [3507, 4670, 8177, 1163]), ('clear', [2482, 3515, 5997, 1033]), ('same', [1804, 2829, 4633, 1025]), ('experimental', [1750, 2686, 4436, 936]), ('hard', [934, 1735, 2669, 801]), ('well', [2339, 3128, 5467, 789]), ('neural', [2407, 3143, 5550, 736]), ('unclear', [713, 1415, 2128, 702]), ('adversarial', [1412, 2076, 3488, 664]), ('main', [2052, 2699, 4751, 647]), ('current', [1024, 1575, 2599, 551]), ('similar', [1496, 2041, 3537, 545]), ('deep', [1551, 2096, 3647, 545]), ('high', [1619, 2150, 3769, 531])]

# %%
x_axis = [ele[0] for ele in rev_to_plot_adj]
accepted_freq = [ele[1][0] for ele in rev_to_plot_adj]
rejected_freq = [ele[1][1] for ele in rev_to_plot_adj]


fig, ax = plt.subplots()

x = np.arange(len(x_axis))  # the label locations
width = 0.35  # the width of the bars

rects1 = ax.bar(x - width/2, accepted_freq, width, label='Accepted papers')
rects2 = ax.bar(x + width/2, rejected_freq, width, label='Rejected papers')

ax.set_ylabel('frequency')
ax.set_xticks(x)
ax.set_xticklabels(x_axis)
ax.legend()
fig.autofmt_xdate()

# autolabel(rects1)
# autolabel(rects2)

plt.savefig("rev_adj.png")
plt.show()
